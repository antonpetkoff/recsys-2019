# %%
import pandas as pd
import tensorflow as tf
import os
from src import dataset_gen, tokenizers
from collections import defaultdict
import numpy as np
from tensorflow.keras import layers

# %%
PATH = 'data/'
train = pd.read_csv(os.path.join(PATH, 'train.csv'))
item_metadata = pd.read_csv(os.path.join(PATH, 'item_metadata.csv'))

# %%
# Treating them as independent... which is definitely not correct
# but anyway
filters_statistics = defaultdict(int)


for filters in train['current_filters'].dropna():
  for current_filter in filters.split('|'):
    filters_statistics[current_filter] += 1

# %%
tokenizers_all = tokenizers.Tokenizer.get_all_tokenizers(train, item_metadata, filters)

# %%
item_metadata.set_index('item_id', inplace=True)

# %%
properties = set()

for i, row in item_metadata.iterrows():
  properties.update(row['properties'].split('|'))

# %%
properties = zip(properties, range(len(properties)))
properties = dict(properties)

# %%
train_length = int(len(train) * 0.8)
train_split = train[:train_length]
val_split = train[train_length:]
len(train_split), len(val_split)
del train

# %%
# DATASET
params = {
    'batch_size': 100,
    'size_items_vectos': len(properties),
    'num_impressions': 25, # Always.. if data is consistent
    'layer_1_units': 1000,
    'layer_2_units': 600,
    'layer_3_units': 200,
}
batch_size = params['batch_size']
fields = ['items', 'impressions_filters', 'prices', 'timestamp']
i = dataset_gen.InputGenerator(tokenizers_all, fields)

def get_dataset_train():
  gen, types, shapes = i.input_generator_gen(train_split,
                                             return_items_filters=True,
                                             item_metadata=item_metadata,
                                             properties=properties,
                                             return_idx=True)
  dataset_train = tf.data.Dataset.from_generator(gen, types)
  dataset_train = dataset_train.repeat().padded_batch(batch_size,
                                                      padded_shapes=shapes)
  batch = dataset_train.make_one_shot_iterator().get_next()
  
  return batch

def get_dataset_eval():
  gen_val, types, shapes = i.input_generator_gen(val_split,
                                                     return_items_filters=True,
                                                     item_metadata=item_metadata,
                                                     properties=properties,
                                                     return_idx=True)
  dataset_val = tf.data.Dataset.from_generator(gen_val, types)
  dataset_val = dataset_val.padded_batch(batch_size,
                                         padded_shapes=shapes)
  batch_val = dataset_val.make_one_shot_iterator().get_next()
  
  return batch_val


steps_per_epoch = len(train_split) // batch_size
validation_steps = len(val_split) // batch_size
# These are not epochs but steps since we're using tf.dataset.
# Out:
# ['items', 'impressions_filters', 'prices', 'timestamp']

# %%
def small_nn_model_fn(
   features, # This is batch_features from input_fn
   labels,   # This is batch_labels from input_fn
   mode,     # An instance of tf.estimator.ModeKeys, see below
   params):  # Additional configuration

  batch_size = params['batch_size'] if mode in [tf.estimator.ModeKeys.TRAIN,
                                                tf.estimator.ModeKeys.EVAL] else 1

  # С този модел запазваме реда на items!!! Така първите ще имат по-голямо тегло.
  _, input_impressions_filters, input_prices, input_timestamp = features
  # input_items.set_shape([None, params['num_impressions']])
  
  input_impressions_filters = tf.cast(input_impressions_filters, dtype=tf.float32)
  input_layer = tf.concat([input_impressions_filters, input_prices], axis=1)
  
  W1 = tf.Variable(tf.random_normal([params['num_impressions'] * (params['size_items_vectos'] + 1),
                                     params['layer_1_units']]))
  b1 = tf.Variable(tf.random_normal([params['layer_1_units']]))
  
  first_layer = tf.nn.relu(tf.matmul(input_layer, W1) + b1)
 
  second_layer = tf.layers.dense(inputs=first_layer,
                                 units=params['layer_2_units'],
                              activation=tf.keras.activations.relu)
  third_layer = tf.layers.dense(inputs=second_layer,
                                units=params['layer_3_units'],
                             activation=tf.keras.activations.relu)
  last_layer = tf.layers.dense(inputs=third_layer,
                               units=params['num_impressions'],
                             activation=tf.keras.activations.softmax)

  predicted_classes = tf.argmax(last_layer, 1)
  predictions = {
      'class_ids': predicted_classes,
      'probabilities': last_layer,
      'timestamp': input_timestamp
  }

  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode, predictions=predictions)
    
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,
                                                logits=last_layer)
  loss = tf.reduce_mean(loss)

  if mode == tf.estimator.ModeKeys.TRAIN:
    tf.summary.scalar('loss-train', tf.reduce_sum(loss))
    optimizer = tf.train.AdamOptimizer(learning_rate=0.0001)
    train_op = optimizer.minimize(
        loss=loss,
        global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)
  
  eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predicted_classes)}
  return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
with tf.Session() as sess:
  sess.run([tf.local_variables_initializer(), tf.tables_initializer()])
  b = sess.run(get_dataset_train())
# Out:
# WARNING:tensorflow:From /home/desi/Desis-Gluposti/Masters/bgqa/bg-reason-BERT/py36/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.

# %%
b[0][1].shape
# Out:
# (100, 3925)

# %%
run_config = tf.estimator.RunConfig(log_step_count_steps=20,
                                    # save_summary_steps=20,
                                    save_checkpoints_steps=100,
                                    keep_checkpoint_max=1)

small_nn_estimator = tf.estimator.Estimator(
  model_fn=small_nn_model_fn,
#  model_dir='./best_model_small_nn',
  params=params,
  config=run_config
)

train_spec = tf.estimator.TrainSpec(input_fn=get_dataset_train,
                                    max_steps=1 * steps_per_epoch)
# throttle_secs=10 lol
eval_spec = tf.estimator.EvalSpec(input_fn=get_dataset_eval,
                                  throttle_secs=30)

tf.estimator.train_and_evaluate(small_nn_estimator, train_spec, eval_spec)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp9k77hrcy
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp9k77hrcy', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 20, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f488a763cf8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 100 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:loss = 3.2551956, step = 1
# INFO:tensorflow:global_step/sec: 1.33541
# INFO:tensorflow:loss = 3.2153482, step = 21 (14.979 sec)
# INFO:tensorflow:global_step/sec: 2.19859
# INFO:tensorflow:loss = 3.2153482, step = 41 (9.097 sec)
# INFO:tensorflow:global_step/sec: 1.80887
# INFO:tensorflow:loss = 3.1653483, step = 61 (11.057 sec)
# INFO:tensorflow:global_step/sec: 1.67598
# INFO:tensorflow:loss = 3.2153482, step = 81 (11.933 sec)
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:00:41Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /home/desi/Desis-Gluposti/Masters/bgqa/bg-reason-BERT/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:01:38
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.0741, global_step = 100, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100: /tmp/tmp9k77hrcy/model.ckpt-100
# INFO:tensorflow:global_step/sec: 0.255442
# INFO:tensorflow:loss = 3.1653483, step = 101 (78.297 sec)
# INFO:tensorflow:global_step/sec: 3.76221
# INFO:tensorflow:loss = 3.2153482, step = 121 (5.313 sec)
# INFO:tensorflow:global_step/sec: 1.71425
# INFO:tensorflow:loss = 3.125348, step = 141 (11.667 sec)
# INFO:tensorflow:global_step/sec: 4.84787
# INFO:tensorflow:loss = 3.2153482, step = 161 (4.126 sec)
# INFO:tensorflow:global_step/sec: 4.4731
# INFO:tensorflow:loss = 3.1953483, step = 181 (4.471 sec)
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:02:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:03:00
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.0741, global_step = 200, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: /tmp/tmp9k77hrcy/model.ckpt-200
# INFO:tensorflow:global_step/sec: 0.363018
# INFO:tensorflow:loss = 3.2453482, step = 201 (55.094 sec)
# INFO:tensorflow:global_step/sec: 4.16049
# INFO:tensorflow:loss = 3.1753483, step = 221 (4.807 sec)
# INFO:tensorflow:global_step/sec: 4.48313
# INFO:tensorflow:loss = 3.2153482, step = 241 (4.461 sec)
# INFO:tensorflow:global_step/sec: 4.34738
# INFO:tensorflow:loss = 3.2153482, step = 261 (4.601 sec)
# INFO:tensorflow:global_step/sec: 4.79065
# INFO:tensorflow:loss = 3.1853483, step = 281 (4.175 sec)
# INFO:tensorflow:Saving checkpoints for 300 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:03:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:03:44
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.0741, global_step = 300, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 300: /tmp/tmp9k77hrcy/model.ckpt-300
# INFO:tensorflow:global_step/sec: 0.756638
# INFO:tensorflow:loss = 3.2153482, step = 301 (26.433 sec)
# INFO:tensorflow:global_step/sec: 4.38292
# INFO:tensorflow:loss = 3.2153482, step = 321 (4.563 sec)
# INFO:tensorflow:global_step/sec: 4.69856
# INFO:tensorflow:loss = 3.2053483, step = 341 (4.257 sec)
# INFO:tensorflow:global_step/sec: 4.95064
# INFO:tensorflow:loss = 3.1653483, step = 361 (4.040 sec)
# INFO:tensorflow:global_step/sec: 4.74781
# INFO:tensorflow:loss = 3.2153482, step = 381 (4.213 sec)
# INFO:tensorflow:Saving checkpoints for 400 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:04:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:04:27
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.0741, global_step = 400, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: /tmp/tmp9k77hrcy/model.ckpt-400
# INFO:tensorflow:global_step/sec: 0.761943
# INFO:tensorflow:loss = 3.2253482, step = 401 (26.249 sec)
# INFO:tensorflow:global_step/sec: 4.68504
# INFO:tensorflow:loss = 3.2153482, step = 421 (4.269 sec)
# INFO:tensorflow:global_step/sec: 4.73149
# INFO:tensorflow:loss = 3.1553483, step = 441 (4.227 sec)
# INFO:tensorflow:global_step/sec: 4.47165
# INFO:tensorflow:loss = 3.2353482, step = 461 (4.473 sec)
# INFO:tensorflow:global_step/sec: 4.57839
# INFO:tensorflow:loss = 3.2253482, step = 481 (4.368 sec)
# INFO:tensorflow:Saving checkpoints for 500 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:04:49Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:05:10
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.0741, global_step = 500, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: /tmp/tmp9k77hrcy/model.ckpt-500
# INFO:tensorflow:global_step/sec: 0.780285
# INFO:tensorflow:loss = 3.2653482, step = 501 (25.632 sec)
# INFO:tensorflow:global_step/sec: 4.72399
# INFO:tensorflow:loss = 3.1853483, step = 521 (4.234 sec)
# INFO:tensorflow:global_step/sec: 4.75396
# INFO:tensorflow:loss = 3.1853483, step = 541 (4.207 sec)
# INFO:tensorflow:global_step/sec: 4.91684
# INFO:tensorflow:loss = 3.1453483, step = 561 (4.068 sec)
# INFO:tensorflow:global_step/sec: 5.40632
# INFO:tensorflow:loss = 3.1853483, step = 581 (3.699 sec)
# INFO:tensorflow:Saving checkpoints for 600 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:05:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:05:53
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.0741, global_step = 600, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 600: /tmp/tmp9k77hrcy/model.ckpt-600
# INFO:tensorflow:global_step/sec: 0.766699
# INFO:tensorflow:loss = 3.2253482, step = 601 (26.086 sec)
# INFO:tensorflow:global_step/sec: 4.96142
# INFO:tensorflow:loss = 3.2353482, step = 621 (4.030 sec)
# INFO:tensorflow:global_step/sec: 4.69357
# INFO:tensorflow:loss = 3.1853483, step = 641 (4.261 sec)
# INFO:tensorflow:global_step/sec: 5.16355
# INFO:tensorflow:loss = 3.2153482, step = 661 (3.874 sec)
# INFO:tensorflow:global_step/sec: 4.52422
# INFO:tensorflow:loss = 3.2153482, step = 681 (4.420 sec)
# INFO:tensorflow:Saving checkpoints for 700 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:06:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:06:35
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.0741, global_step = 700, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 700: /tmp/tmp9k77hrcy/model.ckpt-700
# INFO:tensorflow:global_step/sec: 0.763155
# INFO:tensorflow:loss = 3.115348, step = 701 (26.208 sec)
# INFO:tensorflow:global_step/sec: 4.75022
# INFO:tensorflow:loss = 3.2653482, step = 721 (4.210 sec)
# INFO:tensorflow:global_step/sec: 5.1394
# INFO:tensorflow:loss = 3.1753483, step = 741 (3.892 sec)
# INFO:tensorflow:global_step/sec: 5.00364
# INFO:tensorflow:loss = 3.2553482, step = 761 (3.997 sec)
# INFO:tensorflow:global_step/sec: 4.59263
# INFO:tensorflow:loss = 3.1853483, step = 781 (4.355 sec)
# INFO:tensorflow:Saving checkpoints for 800 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:06:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:07:18
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.0741, global_step = 800, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: /tmp/tmp9k77hrcy/model.ckpt-800
# INFO:tensorflow:global_step/sec: 0.766236
# INFO:tensorflow:loss = 3.125348, step = 801 (26.102 sec)
# INFO:tensorflow:global_step/sec: 4.55428
# INFO:tensorflow:loss = 3.1853483, step = 821 (4.391 sec)
# INFO:tensorflow:global_step/sec: 4.52198
# INFO:tensorflow:loss = 3.2253482, step = 841 (4.423 sec)
# INFO:tensorflow:global_step/sec: 4.49344
# INFO:tensorflow:loss = 3.2453482, step = 861 (4.451 sec)
# INFO:tensorflow:global_step/sec: 4.43523
# INFO:tensorflow:loss = 3.2153482, step = 881 (4.509 sec)
# INFO:tensorflow:Saving checkpoints for 900 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:07:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:08:02
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.0741, global_step = 900, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 900: /tmp/tmp9k77hrcy/model.ckpt-900
# INFO:tensorflow:global_step/sec: 0.761752
# INFO:tensorflow:loss = 3.2353482, step = 901 (26.256 sec)
# INFO:tensorflow:global_step/sec: 4.84451
# INFO:tensorflow:loss = 3.2353482, step = 921 (4.128 sec)
# INFO:tensorflow:global_step/sec: 4.46829
# INFO:tensorflow:loss = 3.2153482, step = 941 (4.476 sec)
# INFO:tensorflow:global_step/sec: 5.20369
# INFO:tensorflow:loss = 3.1453483, step = 961 (3.843 sec)
# INFO:tensorflow:global_step/sec: 4.11161
# INFO:tensorflow:loss = 3.2253482, step = 981 (4.864 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:08:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:08:48
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.0741, global_step = 1000, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmp9k77hrcy/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 0.696777
# INFO:tensorflow:loss = 3.1953483, step = 1001 (28.704 sec)
# INFO:tensorflow:global_step/sec: 3.6239
# INFO:tensorflow:loss = 3.1653483, step = 1021 (5.518 sec)
# INFO:tensorflow:global_step/sec: 4.36664
# INFO:tensorflow:loss = 3.2153482, step = 1041 (4.580 sec)
# INFO:tensorflow:global_step/sec: 4.55348
# INFO:tensorflow:loss = 3.1853483, step = 1061 (4.392 sec)
# INFO:tensorflow:global_step/sec: 3.97173
# INFO:tensorflow:loss = 3.1953483, step = 1081 (5.036 sec)
# INFO:tensorflow:Saving checkpoints for 1100 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:09:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:09:36
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.0741, global_step = 1100, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1100: /tmp/tmp9k77hrcy/model.ckpt-1100
# INFO:tensorflow:global_step/sec: 0.709896
# INFO:tensorflow:loss = 3.1753483, step = 1101 (28.173 sec)
# INFO:tensorflow:global_step/sec: 4.47893
# INFO:tensorflow:loss = 3.1653483, step = 1121 (4.465 sec)
# INFO:tensorflow:global_step/sec: 4.55337
# INFO:tensorflow:loss = 3.2253482, step = 1141 (4.392 sec)
# INFO:tensorflow:global_step/sec: 4.33345
# INFO:tensorflow:loss = 3.2553482, step = 1161 (4.615 sec)
# INFO:tensorflow:global_step/sec: 5.06986
# INFO:tensorflow:loss = 3.2553482, step = 1181 (3.945 sec)
# INFO:tensorflow:Saving checkpoints for 1200 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:09:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:10:20
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.0741, global_step = 1200, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: /tmp/tmp9k77hrcy/model.ckpt-1200
# INFO:tensorflow:global_step/sec: 0.748503
# INFO:tensorflow:loss = 3.1553483, step = 1201 (26.720 sec)
# INFO:tensorflow:global_step/sec: 4.80234
# INFO:tensorflow:loss = 3.2253482, step = 1221 (4.164 sec)
# INFO:tensorflow:global_step/sec: 4.05368
# INFO:tensorflow:loss = 3.2153482, step = 1241 (4.934 sec)
# INFO:tensorflow:global_step/sec: 4.47904
# INFO:tensorflow:loss = 3.1553483, step = 1261 (4.465 sec)
# INFO:tensorflow:global_step/sec: 4.31235
# INFO:tensorflow:loss = 3.2053483, step = 1281 (4.638 sec)
# INFO:tensorflow:Saving checkpoints for 1300 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:10:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:11:07
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.0741, global_step = 1300, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1300: /tmp/tmp9k77hrcy/model.ckpt-1300
# INFO:tensorflow:global_step/sec: 0.683922
# INFO:tensorflow:loss = 3.1953483, step = 1301 (29.244 sec)
# INFO:tensorflow:global_step/sec: 4.40198
# INFO:tensorflow:loss = 3.2153482, step = 1321 (4.543 sec)
# INFO:tensorflow:global_step/sec: 4.45048
# INFO:tensorflow:loss = 3.2253482, step = 1341 (4.494 sec)
# INFO:tensorflow:global_step/sec: 4.39622
# INFO:tensorflow:loss = 3.1753483, step = 1361 (4.549 sec)
# INFO:tensorflow:global_step/sec: 4.5356
# INFO:tensorflow:loss = 3.2253482, step = 1381 (4.410 sec)
# INFO:tensorflow:Saving checkpoints for 1400 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:11:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:11:53
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.0741, global_step = 1400, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1400: /tmp/tmp9k77hrcy/model.ckpt-1400
# INFO:tensorflow:global_step/sec: 0.71918
# INFO:tensorflow:loss = 3.1753483, step = 1401 (27.810 sec)
# INFO:tensorflow:global_step/sec: 4.70491
# INFO:tensorflow:loss = 3.2153482, step = 1421 (4.251 sec)
# INFO:tensorflow:global_step/sec: 4.82506
# INFO:tensorflow:loss = 3.2553482, step = 1441 (4.145 sec)
# INFO:tensorflow:global_step/sec: 4.51465
# INFO:tensorflow:loss = 3.1453483, step = 1461 (4.430 sec)
# INFO:tensorflow:global_step/sec: 4.68542
# INFO:tensorflow:loss = 3.2053483, step = 1481 (4.269 sec)
# INFO:tensorflow:Saving checkpoints for 1500 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:12:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:12:38
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.0741, global_step = 1500, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1500: /tmp/tmp9k77hrcy/model.ckpt-1500
# INFO:tensorflow:global_step/sec: 0.729784
# INFO:tensorflow:loss = 3.2253482, step = 1501 (27.406 sec)
# INFO:tensorflow:global_step/sec: 4.3548
# INFO:tensorflow:loss = 3.1753483, step = 1521 (4.592 sec)
# INFO:tensorflow:global_step/sec: 4.70963
# INFO:tensorflow:loss = 3.1653483, step = 1541 (4.247 sec)
# INFO:tensorflow:global_step/sec: 3.96303
# INFO:tensorflow:loss = 3.2453482, step = 1561 (5.046 sec)
# INFO:tensorflow:global_step/sec: 4.32914
# INFO:tensorflow:loss = 3.2453482, step = 1581 (4.620 sec)
# INFO:tensorflow:Saving checkpoints for 1600 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:13:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:13:23
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.0741, global_step = 1600, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1600: /tmp/tmp9k77hrcy/model.ckpt-1600
# INFO:tensorflow:global_step/sec: 0.742567
# INFO:tensorflow:loss = 3.2553482, step = 1601 (26.934 sec)
# INFO:tensorflow:global_step/sec: 4.40199
# INFO:tensorflow:loss = 3.1753483, step = 1621 (4.543 sec)
# INFO:tensorflow:global_step/sec: 4.74419
# INFO:tensorflow:loss = 3.115348, step = 1641 (4.216 sec)
# INFO:tensorflow:global_step/sec: 4.65581
# INFO:tensorflow:loss = 3.2153482, step = 1661 (4.296 sec)
# INFO:tensorflow:global_step/sec: 4.40636
# INFO:tensorflow:loss = 3.2253482, step = 1681 (4.539 sec)
# INFO:tensorflow:Saving checkpoints for 1700 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:13:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:14:08
# INFO:tensorflow:Saving dict for global step 1700: accuracy = 0.0741, global_step = 1700, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1700: /tmp/tmp9k77hrcy/model.ckpt-1700
# INFO:tensorflow:global_step/sec: 0.733185
# INFO:tensorflow:loss = 3.2353482, step = 1701 (27.279 sec)
# INFO:tensorflow:global_step/sec: 4.56221
# INFO:tensorflow:loss = 3.2253482, step = 1721 (4.383 sec)
# INFO:tensorflow:global_step/sec: 4.44411
# INFO:tensorflow:loss = 3.2253482, step = 1741 (4.500 sec)
# INFO:tensorflow:global_step/sec: 4.7118
# INFO:tensorflow:loss = 3.1653483, step = 1761 (4.245 sec)
# INFO:tensorflow:global_step/sec: 4.26072
# INFO:tensorflow:loss = 3.1853483, step = 1781 (4.694 sec)
# INFO:tensorflow:Saving checkpoints for 1800 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:14:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:14:53
# INFO:tensorflow:Saving dict for global step 1800: accuracy = 0.0741, global_step = 1800, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1800: /tmp/tmp9k77hrcy/model.ckpt-1800
# INFO:tensorflow:global_step/sec: 0.740052
# INFO:tensorflow:loss = 3.2353482, step = 1801 (27.026 sec)
# INFO:tensorflow:global_step/sec: 4.42601
# INFO:tensorflow:loss = 3.2153482, step = 1821 (4.518 sec)
# INFO:tensorflow:global_step/sec: 4.30001
# INFO:tensorflow:loss = 3.1953483, step = 1841 (4.651 sec)
# INFO:tensorflow:global_step/sec: 4.7587
# INFO:tensorflow:loss = 3.2053483, step = 1861 (4.203 sec)
# INFO:tensorflow:global_step/sec: 4.0815
# INFO:tensorflow:loss = 3.2453482, step = 1881 (4.900 sec)
# INFO:tensorflow:Saving checkpoints for 1900 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:15:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-1900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:15:38
# INFO:tensorflow:Saving dict for global step 1900: accuracy = 0.0741, global_step = 1900, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1900: /tmp/tmp9k77hrcy/model.ckpt-1900
# INFO:tensorflow:global_step/sec: 0.750756
# INFO:tensorflow:loss = 3.2253482, step = 1901 (26.640 sec)
# INFO:tensorflow:global_step/sec: 4.87106
# INFO:tensorflow:loss = 3.2253482, step = 1921 (4.106 sec)
# INFO:tensorflow:global_step/sec: 4.24088
# INFO:tensorflow:loss = 3.2053483, step = 1941 (4.716 sec)
# INFO:tensorflow:global_step/sec: 4.47035
# INFO:tensorflow:loss = 3.1853483, step = 1961 (4.474 sec)
# INFO:tensorflow:global_step/sec: 4.18136
# INFO:tensorflow:loss = 3.2453482, step = 1981 (4.783 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:16:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:16:23
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.0741, global_step = 2000, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: /tmp/tmp9k77hrcy/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 0.742534
# INFO:tensorflow:loss = 3.1953483, step = 2001 (26.936 sec)
# INFO:tensorflow:global_step/sec: 4.67268
# INFO:tensorflow:loss = 3.2153482, step = 2021 (4.279 sec)
# INFO:tensorflow:global_step/sec: 4.14862
# INFO:tensorflow:loss = 3.2253482, step = 2041 (4.821 sec)
# INFO:tensorflow:global_step/sec: 4.25074
# INFO:tensorflow:loss = 3.2353482, step = 2061 (4.705 sec)
# INFO:tensorflow:global_step/sec: 4.294
# INFO:tensorflow:loss = 3.2553482, step = 2081 (4.658 sec)
# INFO:tensorflow:Saving checkpoints for 2100 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:16:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:17:08
# INFO:tensorflow:Saving dict for global step 2100: accuracy = 0.0741, global_step = 2100, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2100: /tmp/tmp9k77hrcy/model.ckpt-2100
# INFO:tensorflow:global_step/sec: 0.750969
# INFO:tensorflow:loss = 3.2553482, step = 2101 (26.633 sec)
# INFO:tensorflow:global_step/sec: 4.39915
# INFO:tensorflow:loss = 3.2353482, step = 2121 (4.546 sec)
# INFO:tensorflow:global_step/sec: 4.61612
# INFO:tensorflow:loss = 3.2153482, step = 2141 (4.333 sec)
# INFO:tensorflow:global_step/sec: 4.69511
# INFO:tensorflow:loss = 3.1953483, step = 2161 (4.260 sec)
# INFO:tensorflow:global_step/sec: 4.56931
# INFO:tensorflow:loss = 3.1653483, step = 2181 (4.377 sec)
# INFO:tensorflow:Saving checkpoints for 2200 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:17:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:17:53
# INFO:tensorflow:Saving dict for global step 2200: accuracy = 0.0741, global_step = 2200, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2200: /tmp/tmp9k77hrcy/model.ckpt-2200
# INFO:tensorflow:global_step/sec: 0.723333
# INFO:tensorflow:loss = 3.1953483, step = 2201 (27.650 sec)
# INFO:tensorflow:global_step/sec: 4.29748
# INFO:tensorflow:loss = 3.2253482, step = 2221 (4.654 sec)
# INFO:tensorflow:global_step/sec: 4.37911
# INFO:tensorflow:loss = 3.2153482, step = 2241 (4.567 sec)
# INFO:tensorflow:global_step/sec: 4.42564
# INFO:tensorflow:loss = 3.1853483, step = 2261 (4.519 sec)
# INFO:tensorflow:global_step/sec: 3.90312
# INFO:tensorflow:loss = 3.2653482, step = 2281 (5.124 sec)
# INFO:tensorflow:Saving checkpoints for 2300 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:18:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:18:40
# INFO:tensorflow:Saving dict for global step 2300: accuracy = 0.0741, global_step = 2300, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2300: /tmp/tmp9k77hrcy/model.ckpt-2300
# INFO:tensorflow:global_step/sec: 0.71924
# INFO:tensorflow:loss = 3.1953483, step = 2301 (27.807 sec)
# INFO:tensorflow:global_step/sec: 4.49382
# INFO:tensorflow:loss = 3.1753483, step = 2321 (4.450 sec)
# INFO:tensorflow:global_step/sec: 4.77805
# INFO:tensorflow:loss = 3.2153482, step = 2341 (4.186 sec)
# INFO:tensorflow:global_step/sec: 4.14041
# INFO:tensorflow:loss = 3.1853483, step = 2361 (4.830 sec)
# INFO:tensorflow:global_step/sec: 4.53087
# INFO:tensorflow:loss = 3.2353482, step = 2381 (4.414 sec)
# INFO:tensorflow:Saving checkpoints for 2400 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:19:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:19:25
# INFO:tensorflow:Saving dict for global step 2400: accuracy = 0.0741, global_step = 2400, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2400: /tmp/tmp9k77hrcy/model.ckpt-2400
# INFO:tensorflow:global_step/sec: 0.743499
# INFO:tensorflow:loss = 3.2253482, step = 2401 (26.900 sec)
# INFO:tensorflow:global_step/sec: 4.66487
# INFO:tensorflow:loss = 3.2153482, step = 2421 (4.287 sec)
# INFO:tensorflow:global_step/sec: 4.14067
# INFO:tensorflow:loss = 3.1853483, step = 2441 (4.830 sec)
# INFO:tensorflow:global_step/sec: 4.36221
# INFO:tensorflow:loss = 3.1953483, step = 2461 (4.585 sec)
# INFO:tensorflow:global_step/sec: 4.57944
# INFO:tensorflow:loss = 3.2553482, step = 2481 (4.367 sec)
# INFO:tensorflow:Saving checkpoints for 2500 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:19:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:20:10
# INFO:tensorflow:Saving dict for global step 2500: accuracy = 0.0741, global_step = 2500, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2500: /tmp/tmp9k77hrcy/model.ckpt-2500
# INFO:tensorflow:global_step/sec: 0.715428
# INFO:tensorflow:loss = 3.1653483, step = 2501 (27.956 sec)
# INFO:tensorflow:global_step/sec: 4.31784
# INFO:tensorflow:loss = 3.1453483, step = 2521 (4.632 sec)
# INFO:tensorflow:global_step/sec: 4.64495
# INFO:tensorflow:loss = 3.2053483, step = 2541 (4.306 sec)
# INFO:tensorflow:global_step/sec: 4.41314
# INFO:tensorflow:loss = 3.2453482, step = 2561 (4.532 sec)
# INFO:tensorflow:global_step/sec: 4.06726
# INFO:tensorflow:loss = 3.1953483, step = 2581 (4.918 sec)
# INFO:tensorflow:Saving checkpoints for 2600 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:20:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:20:57
# INFO:tensorflow:Saving dict for global step 2600: accuracy = 0.0741, global_step = 2600, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2600: /tmp/tmp9k77hrcy/model.ckpt-2600
# INFO:tensorflow:global_step/sec: 0.712125
# INFO:tensorflow:loss = 3.2353482, step = 2601 (28.085 sec)
# INFO:tensorflow:global_step/sec: 4.90989
# INFO:tensorflow:loss = 3.2253482, step = 2621 (4.073 sec)
# INFO:tensorflow:global_step/sec: 4.483
# INFO:tensorflow:loss = 3.2553482, step = 2641 (4.461 sec)
# INFO:tensorflow:global_step/sec: 4.41656
# INFO:tensorflow:loss = 3.2053483, step = 2661 (4.528 sec)
# INFO:tensorflow:global_step/sec: 4.45539
# INFO:tensorflow:loss = 3.2253482, step = 2681 (4.489 sec)
# INFO:tensorflow:Saving checkpoints for 2700 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:21:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:21:42
# INFO:tensorflow:Saving dict for global step 2700: accuracy = 0.0741, global_step = 2700, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2700: /tmp/tmp9k77hrcy/model.ckpt-2700
# INFO:tensorflow:global_step/sec: 0.731011
# INFO:tensorflow:loss = 3.2353482, step = 2701 (27.360 sec)
# INFO:tensorflow:global_step/sec: 4.25506
# INFO:tensorflow:loss = 3.2653482, step = 2721 (4.699 sec)
# INFO:tensorflow:global_step/sec: 4.23321
# INFO:tensorflow:loss = 3.1953483, step = 2741 (4.724 sec)
# INFO:tensorflow:global_step/sec: 4.40694
# INFO:tensorflow:loss = 3.2353482, step = 2761 (4.538 sec)
# INFO:tensorflow:global_step/sec: 4.17187
# INFO:tensorflow:loss = 3.1853483, step = 2781 (4.794 sec)
# INFO:tensorflow:Saving checkpoints for 2800 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:22:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:22:28
# INFO:tensorflow:Saving dict for global step 2800: accuracy = 0.0741, global_step = 2800, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: /tmp/tmp9k77hrcy/model.ckpt-2800
# INFO:tensorflow:global_step/sec: 0.723156
# INFO:tensorflow:loss = 3.2353482, step = 2801 (27.657 sec)
# INFO:tensorflow:global_step/sec: 4.2436
# INFO:tensorflow:loss = 3.1953483, step = 2821 (4.713 sec)
# INFO:tensorflow:global_step/sec: 4.54929
# INFO:tensorflow:loss = 3.2453482, step = 2841 (4.396 sec)
# INFO:tensorflow:global_step/sec: 4.80339
# INFO:tensorflow:loss = 3.1953483, step = 2861 (4.163 sec)
# INFO:tensorflow:global_step/sec: 4.28208
# INFO:tensorflow:loss = 3.2353482, step = 2881 (4.671 sec)
# INFO:tensorflow:Saving checkpoints for 2900 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:22:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-2900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:23:14
# INFO:tensorflow:Saving dict for global step 2900: accuracy = 0.0741, global_step = 2900, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2900: /tmp/tmp9k77hrcy/model.ckpt-2900
# INFO:tensorflow:global_step/sec: 0.714314
# INFO:tensorflow:loss = 3.2253482, step = 2901 (27.999 sec)
# INFO:tensorflow:global_step/sec: 4.22676
# INFO:tensorflow:loss = 3.1853483, step = 2921 (4.732 sec)
# INFO:tensorflow:global_step/sec: 4.70223
# INFO:tensorflow:loss = 3.2553482, step = 2941 (4.254 sec)
# INFO:tensorflow:global_step/sec: 4.34596
# INFO:tensorflow:loss = 3.2153482, step = 2961 (4.602 sec)
# INFO:tensorflow:global_step/sec: 4.37151
# INFO:tensorflow:loss = 3.2053483, step = 2981 (4.575 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:23:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:24:00
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.0741, global_step = 3000, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: /tmp/tmp9k77hrcy/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 0.728793
# INFO:tensorflow:loss = 3.2253482, step = 3001 (27.443 sec)
# INFO:tensorflow:global_step/sec: 4.0772
# INFO:tensorflow:loss = 3.1953483, step = 3021 (4.905 sec)
# INFO:tensorflow:global_step/sec: 4.44824
# ...
# INFO:tensorflow:Saving checkpoints for 3200 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:25:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:25:31
# INFO:tensorflow:Saving dict for global step 3200: accuracy = 0.0741, global_step = 3200, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3200: /tmp/tmp9k77hrcy/model.ckpt-3200
# INFO:tensorflow:global_step/sec: 0.738039
# INFO:tensorflow:loss = 3.2153482, step = 3201 (27.099 sec)
# INFO:tensorflow:global_step/sec: 4.09999
# INFO:tensorflow:loss = 3.1953483, step = 3221 (4.878 sec)
# INFO:tensorflow:global_step/sec: 4.14076
# INFO:tensorflow:loss = 3.2053483, step = 3241 (4.830 sec)
# INFO:tensorflow:global_step/sec: 4.17023
# INFO:tensorflow:loss = 3.2153482, step = 3261 (4.796 sec)
# INFO:tensorflow:global_step/sec: 4.54791
# INFO:tensorflow:loss = 3.2453482, step = 3281 (4.397 sec)
# INFO:tensorflow:Saving checkpoints for 3300 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:25:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:26:18
# INFO:tensorflow:Saving dict for global step 3300: accuracy = 0.0741, global_step = 3300, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3300: /tmp/tmp9k77hrcy/model.ckpt-3300
# INFO:tensorflow:global_step/sec: 0.714425
# INFO:tensorflow:loss = 3.2353482, step = 3301 (27.995 sec)
# INFO:tensorflow:global_step/sec: 4.26853
# INFO:tensorflow:loss = 3.1353483, step = 3321 (4.685 sec)
# INFO:tensorflow:global_step/sec: 4.38568
# INFO:tensorflow:loss = 3.1953483, step = 3341 (4.560 sec)
# INFO:tensorflow:global_step/sec: 4.5864
# INFO:tensorflow:loss = 3.2353482, step = 3361 (4.361 sec)
# INFO:tensorflow:global_step/sec: 4.19168
# INFO:tensorflow:loss = 3.2053483, step = 3381 (4.771 sec)
# INFO:tensorflow:Saving checkpoints for 3400 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:26:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:27:03
# INFO:tensorflow:Saving dict for global step 3400: accuracy = 0.0741, global_step = 3400, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3400: /tmp/tmp9k77hrcy/model.ckpt-3400
# INFO:tensorflow:global_step/sec: 0.733303
# INFO:tensorflow:loss = 3.2253482, step = 3401 (27.275 sec)
# INFO:tensorflow:global_step/sec: 4.09411
# INFO:tensorflow:loss = 3.2253482, step = 3421 (4.884 sec)
# INFO:tensorflow:global_step/sec: 4.0086
# INFO:tensorflow:loss = 3.1953483, step = 3441 (4.989 sec)
# INFO:tensorflow:global_step/sec: 4.38063
# INFO:tensorflow:loss = 3.2253482, step = 3461 (4.565 sec)
# INFO:tensorflow:global_step/sec: 4.4946
# INFO:tensorflow:loss = 3.1953483, step = 3481 (4.450 sec)
# INFO:tensorflow:Saving checkpoints for 3500 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:27:27Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:27:50
# INFO:tensorflow:Saving dict for global step 3500: accuracy = 0.0741, global_step = 3500, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3500: /tmp/tmp9k77hrcy/model.ckpt-3500
# INFO:tensorflow:global_step/sec: 0.714789
# INFO:tensorflow:loss = 3.2353482, step = 3501 (27.981 sec)
# INFO:tensorflow:global_step/sec: 4.2733
# INFO:tensorflow:loss = 3.2453482, step = 3521 (4.680 sec)
# INFO:tensorflow:global_step/sec: 4.16065
# INFO:tensorflow:loss = 3.1853483, step = 3541 (4.807 sec)
# INFO:tensorflow:global_step/sec: 4.45115
# INFO:tensorflow:loss = 3.2453482, step = 3561 (4.493 sec)
# INFO:tensorflow:global_step/sec: 4.31587
# INFO:tensorflow:loss = 3.1753483, step = 3581 (4.634 sec)
# INFO:tensorflow:Saving checkpoints for 3600 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:28:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:28:36
# INFO:tensorflow:Saving dict for global step 3600: accuracy = 0.0741, global_step = 3600, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3600: /tmp/tmp9k77hrcy/model.ckpt-3600
# INFO:tensorflow:global_step/sec: 0.7259
# INFO:tensorflow:loss = 3.2053483, step = 3601 (27.553 sec)
# INFO:tensorflow:global_step/sec: 4.39677
# INFO:tensorflow:loss = 3.1753483, step = 3621 (4.548 sec)
# INFO:tensorflow:global_step/sec: 4.34249
# INFO:tensorflow:loss = 3.2153482, step = 3641 (4.606 sec)
# INFO:tensorflow:global_step/sec: 4.41677
# INFO:tensorflow:loss = 3.2253482, step = 3661 (4.528 sec)
# INFO:tensorflow:global_step/sec: 4.19536
# INFO:tensorflow:loss = 3.2153482, step = 3681 (4.768 sec)
# INFO:tensorflow:Saving checkpoints for 3700 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:29:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:29:23
# INFO:tensorflow:Saving dict for global step 3700: accuracy = 0.0741, global_step = 3700, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3700: /tmp/tmp9k77hrcy/model.ckpt-3700
# INFO:tensorflow:global_step/sec: 0.719942
# INFO:tensorflow:loss = 3.2353482, step = 3701 (27.780 sec)
# INFO:tensorflow:global_step/sec: 4.22789
# INFO:tensorflow:loss = 3.2353482, step = 3721 (4.731 sec)
# INFO:tensorflow:global_step/sec: 4.21409
# INFO:tensorflow:loss = 3.2053483, step = 3741 (4.746 sec)
# INFO:tensorflow:global_step/sec: 4.30851
# INFO:tensorflow:loss = 3.2253482, step = 3761 (4.642 sec)
# INFO:tensorflow:global_step/sec: 4.22598
# INFO:tensorflow:loss = 3.2053483, step = 3781 (4.733 sec)
# INFO:tensorflow:Saving checkpoints for 3800 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:29:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:30:09
# INFO:tensorflow:Saving dict for global step 3800: accuracy = 0.0741, global_step = 3800, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3800: /tmp/tmp9k77hrcy/model.ckpt-3800
# INFO:tensorflow:global_step/sec: 0.715773
# INFO:tensorflow:loss = 3.1853483, step = 3801 (27.942 sec)
# INFO:tensorflow:global_step/sec: 4.539
# INFO:tensorflow:loss = 3.1753483, step = 3821 (4.406 sec)
# INFO:tensorflow:global_step/sec: 4.38523
# INFO:tensorflow:loss = 3.1953483, step = 3841 (4.561 sec)
# INFO:tensorflow:global_step/sec: 4.10712
# INFO:tensorflow:loss = 3.1553483, step = 3861 (4.870 sec)
# INFO:tensorflow:global_step/sec: 4.2284
# INFO:tensorflow:loss = 3.2453482, step = 3881 (4.730 sec)
# INFO:tensorflow:Saving checkpoints for 3900 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:30:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-3900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:30:56
# INFO:tensorflow:Saving dict for global step 3900: accuracy = 0.0741, global_step = 3900, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3900: /tmp/tmp9k77hrcy/model.ckpt-3900
# INFO:tensorflow:global_step/sec: 0.718794
# INFO:tensorflow:loss = 3.1553483, step = 3901 (27.825 sec)
# INFO:tensorflow:global_step/sec: 3.84783
# INFO:tensorflow:loss = 3.2353482, step = 3921 (5.197 sec)
# INFO:tensorflow:global_step/sec: 4.2201
# INFO:tensorflow:loss = 3.2353482, step = 3941 (4.739 sec)
# INFO:tensorflow:global_step/sec: 4.27193
# INFO:tensorflow:loss = 3.2553482, step = 3961 (4.681 sec)
# INFO:tensorflow:global_step/sec: 4.62766
# INFO:tensorflow:loss = 3.2553482, step = 3981 (4.322 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:31:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:31:44
# INFO:tensorflow:Saving dict for global step 4000: accuracy = 0.0741, global_step = 4000, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: /tmp/tmp9k77hrcy/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 0.675281
# INFO:tensorflow:loss = 3.2153482, step = 4001 (29.618 sec)
# INFO:tensorflow:global_step/sec: 3.82096
# INFO:tensorflow:loss = 3.1853483, step = 4021 (5.234 sec)
# INFO:tensorflow:global_step/sec: 4.32038
# INFO:tensorflow:loss = 3.2253482, step = 4041 (4.629 sec)
# INFO:tensorflow:global_step/sec: 4.57024
# INFO:tensorflow:loss = 3.2253482, step = 4061 (4.376 sec)
# INFO:tensorflow:global_step/sec: 4.40431
# INFO:tensorflow:loss = 3.1553483, step = 4081 (4.541 sec)
# INFO:tensorflow:Saving checkpoints for 4100 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:32:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-4100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-06-23-20:32:32
# INFO:tensorflow:Saving dict for global step 4100: accuracy = 0.0741, global_step = 4100, loss = 3.211248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4100: /tmp/tmp9k77hrcy/model.ckpt-4100
# INFO:tensorflow:global_step/sec: 0.695536
# INFO:tensorflow:loss = 3.2153482, step = 4101 (28.755 sec)
# INFO:tensorflow:global_step/sec: 4.05786
# INFO:tensorflow:loss = 3.1553483, step = 4121 (4.928 sec)
# INFO:tensorflow:global_step/sec: 4.51874
# INFO:tensorflow:loss = 3.2353482, step = 4141 (4.426 sec)
# INFO:tensorflow:global_step/sec: 4.31701
# INFO:tensorflow:loss = 3.1853483, step = 4161 (4.633 sec)
# INFO:tensorflow:global_step/sec: 4.30749
# INFO:tensorflow:loss = 3.2453482, step = 4181 (4.643 sec)
# INFO:tensorflow:Saving checkpoints for 4200 into /tmp/tmp9k77hrcy/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T20:32:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9k77hrcy/model.ckpt-4200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]

# %%
np.array([[1,2]]).reshape(-1).tolist()

# %%
0 in item_metadata.index
