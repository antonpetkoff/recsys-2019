# %%
import pandas as pd
import tensorflow as tf
import os
from src import dataset_gen, tokenizers
from collections import defaultdict
import numpy as np
from tensorflow.keras import layers

# %%
PATH = 'data/'
train = pd.read_csv(os.path.join(PATH, 'train.csv'))
item_metadata = pd.read_csv(os.path.join(PATH, 'item_metadata.csv'))

# %%
# Treating them as independent... which is definitely not correct
# but anyway
filters_statistics = defaultdict(int)


for filters in train['current_filters'].dropna():
  for current_filter in filters.split('|'):
    filters_statistics[current_filter] += 1

# %%
tokenizers_all = tokenizers.Tokenizer.get_all_tokenizers(train, item_metadata, filters)

# %%
item_metadata.set_index('item_id', inplace=True)

# %%
properties = set()

for i, row in item_metadata.iterrows():
  properties.update(row['properties'].split('|'))

# %%
properties = zip(properties, range(len(properties)))
properties = dict(properties)

# %%
train_length = int(len(train) * 0.8)
train_split = train[:train_length]
val_split = train[train_length:]
len(train_split), len(val_split)
del train

# %%
# DATASET
params = {
    'batch_size': 100,
    'size_items_vectos': len(properties),
    'num_impressions': 25, # Always.. if data is consistent
    'layer_1_units': 1000,
    'layer_2_units': 600,
    'layer_3_units': 200,
}
batch_size = params['batch_size']
fields = ['items', 'impressions_filters', 'prices', 'timestamp']
i = dataset_gen.InputGenerator(tokenizers_all, fields)

def get_dataset_train():
  gen, types, shapes = i.input_generator_gen(train_split,
                                             return_items_filters=True,
                                             item_metadata=item_metadata,
                                             properties=properties,
                                             return_idx=True)
  dataset_train = tf.data.Dataset.from_generator(gen, types)
  dataset_train = dataset_train.repeat().padded_batch(batch_size,
                                                      padded_shapes=shapes)
  batch = dataset_train.make_one_shot_iterator().get_next()
  
  return batch

def get_dataset_eval():
  gen_val, types, shapes = i.input_generator_gen(val_split,
                                                     return_items_filters=True,
                                                     item_metadata=item_metadata,
                                                     properties=properties,
                                                     return_idx=True)
  dataset_val = tf.data.Dataset.from_generator(gen_val, types)
  dataset_val = dataset_val.padded_batch(batch_size,
                                         padded_shapes=shapes)
  batch_val = dataset_val.make_one_shot_iterator().get_next()
  
  return batch_val


steps_per_epoch = len(train_split) // batch_size
validation_steps = len(val_split) // batch_size
# These are not epochs but steps since we're using tf.dataset.
# Out:
# ['items', 'impressions_filters', 'prices', 'timestamp']

# %%
tf.logging.set_verbosity(tf.logging.INFO)

# %%
def small_nn_model_fn(
   features, # This is batch_features from input_fn
   labels,   # This is batch_labels from input_fn
   mode,     # An instance of tf.estimator.ModeKeys, see below
   params):  # Additional configuration

  batch_size = params['batch_size'] if mode in [tf.estimator.ModeKeys.TRAIN,
                                                tf.estimator.ModeKeys.EVAL] else 1

  # С този модел запазваме реда на items!!! Така първите ще имат по-голямо тегло.
  _, input_impressions_filters, input_prices, input_timestamp = features
  # input_items.set_shape([None, params['num_impressions']])
  
  input_impressions_filters = tf.cast(input_impressions_filters, dtype=tf.float32)
  input_layer = tf.concat([input_impressions_filters, input_prices], axis=1)
  
  W1 = tf.Variable(tf.random_normal([params['num_impressions'] * (params['size_items_vectos'] + 1),
                                     params['layer_1_units']]))
  b1 = tf.Variable(tf.random_normal([params['layer_1_units']]))
  
  first_layer = tf.nn.relu(tf.matmul(input_layer, W1) + b1)
 
  second_layer = tf.layers.dense(inputs=first_layer,
                                 units=params['layer_2_units'],
                              activation=tf.keras.activations.relu)
  third_layer = tf.layers.dense(inputs=second_layer,
                                units=params['layer_3_units'],
                             activation=tf.keras.activations.relu)
  last_layer = tf.layers.dense(inputs=third_layer,
                               units=params['num_impressions'],
                             activation=tf.keras.activations.softmax)

  predicted_classes = tf.argmax(last_layer, 1)
  predictions = {
      'class_ids': predicted_classes,
      'probabilities': last_layer,
      'timestamp': input_timestamp
  }

  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode, predictions=predictions)
  
  
  predicted_classes
  
  
  sorted_probs = tf.argsort(last_layer, axis=1)
  # https://stackoverflow.com/questions/47759777/tensorflow-get-indices-of-values-in-a-tensor
  idxs = tf.where(tf.equal(sorted_probs, tf.expand_dims(labels, 1)))[:,-1]
  mrr = tf.reduce_mean(idxs / params['num_impressions'])

  
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels,
                                                logits=last_layer)
  loss = tf.reduce_mean(loss)

  if mode == tf.estimator.ModeKeys.TRAIN:
    tf.summary.scalar('loss-train', tf.reduce_sum(loss))
    optimizer = tf.train.AdamOptimizer(learning_rate=0.0001)
    train_op = optimizer.minimize(
        loss=loss,
        global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)
  
  hook = tf.train.LoggingTensorHook({"mrr:": mrr},
                                     every_n_iter=1)
  eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predicted_classes)}
  return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops, evaluation_hooks=[hook])

# %%
run_config = tf.estimator.RunConfig(log_step_count_steps=20,
                                    # save_summary_steps=20,
                                    save_checkpoints_steps=100,
                                    keep_checkpoint_max=1)

small_nn_estimator = tf.estimator.Estimator(
  model_fn=small_nn_model_fn,
  model_dir='./model_small_nn',
  params=params,
  config=run_config
)

train_spec = tf.estimator.TrainSpec(input_fn=get_dataset_train,
                                    max_steps=1 * steps_per_epoch)
# throttle_secs=10 lol
eval_spec = tf.estimator.EvalSpec(input_fn=get_dataset_eval,
                                  throttle_secs=30)

tf.estimator.train_and_evaluate(small_nn_estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './model_small_nn', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 20, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f49a030c908>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 100 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 600 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:loss = 3.2853482, step = 601
# INFO:tensorflow:global_step/sec: 4.079
# INFO:tensorflow:loss = 3.2753482, step = 621 (4.904 sec)
# INFO:tensorflow:global_step/sec: 4.20023
# INFO:tensorflow:loss = 3.2253482, step = 641 (4.762 sec)
# INFO:tensorflow:global_step/sec: 3.78118
# INFO:tensorflow:loss = 3.2753482, step = 661 (5.289 sec)
# INFO:tensorflow:global_step/sec: 3.92688
# INFO:tensorflow:loss = 3.2853482, step = 681 (5.093 sec)
# INFO:tensorflow:Saving checkpoints for 700 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T21:22:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:mrr: = 0.19999999999999993
# INFO:tensorflow:mrr: = 0.13920000000000005 (0.235 sec)
# INFO:tensorflow:mrr: = 0.2348000000000003 (0.170 sec)
# INFO:tensorflow:mrr: = 0.20599999999999946 (0.445 sec)
# INFO:tensorflow:mrr: = 0.25200000000000033 (0.365 sec)
# INFO:tensorflow:mrr: = 0.2304000000000001 (0.246 sec)
# INFO:tensorflow:mrr: = 0.23920000000000008 (0.476 sec)
# INFO:tensorflow:mrr: = 0.2196000000000009 (0.235 sec)
# INFO:tensorflow:mrr: = 0.1943999999999995 (0.216 sec)
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:mrr: = 0.2087999999999999 (0.204 sec)
# INFO:tensorflow:mrr: = 0.2312 (0.240 sec)
# INFO:tensorflow:mrr: = 0.14839999999999995 (0.191 sec)
# INFO:tensorflow:mrr: = 0.19840000000000016 (0.237 sec)
# INFO:tensorflow:mrr: = 0.11839999999999969 (0.187 sec)
# INFO:tensorflow:mrr: = 0.26279999999999987 (0.148 sec)
# INFO:tensorflow:mrr: = 0.25520000000000026 (0.219 sec)
# INFO:tensorflow:mrr: = 0.2079999999999999 (0.178 sec)
# INFO:tensorflow:mrr: = 0.19119999999999993 (0.171 sec)
# INFO:tensorflow:mrr: = 0.2832000000000006 (0.252 sec)
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:mrr: = 0.25120000000000053 (0.246 sec)
# INFO:tensorflow:mrr: = 0.20319999999999955 (0.217 sec)
# INFO:tensorflow:mrr: = 0.23000000000000073 (0.193 sec)
# INFO:tensorflow:mrr: = 0.2124000000000001 (0.232 sec)
# INFO:tensorflow:mrr: = 0.26840000000000047 (0.170 sec)
# INFO:tensorflow:mrr: = 0.18880000000000002 (0.253 sec)
# INFO:tensorflow:mrr: = 0.16080000000000008 (0.239 sec)
# INFO:tensorflow:mrr: = 0.2692000000000003 (0.212 sec)
# INFO:tensorflow:mrr: = 0.22960000000000064 (0.254 sec)
# INFO:tensorflow:mrr: = 0.22640000000000018 (0.231 sec)
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:mrr: = 0.2272000000000001 (0.208 sec)
# INFO:tensorflow:mrr: = 0.19599999999999965 (0.179 sec)
# INFO:tensorflow:mrr: = 0.14279999999999995 (0.274 sec)
# INFO:tensorflow:mrr: = 0.21959999999999977 (0.243 sec)
# INFO:tensorflow:mrr: = 0.25760000000000055 (0.252 sec)
# INFO:tensorflow:mrr: = 0.24480000000000018 (0.437 sec)
# INFO:tensorflow:mrr: = 0.22699600000000028 (0.348 sec)
# INFO:tensorflow:mrr: = 0.18640000000000018 (0.138 sec)
# INFO:tensorflow:mrr: = 0.19879999999999973 (0.229 sec)
# INFO:tensorflow:mrr: = 0.30880000000000074 (0.222 sec)
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:mrr: = 0.21600000000000036 (0.274 sec)
# INFO:tensorflow:mrr: = 0.1623999999999996 (0.172 sec)
# INFO:tensorflow:mrr: = 0.17360000000000006 (0.198 sec)
# INFO:tensorflow:mrr: = 0.1988000000000001 (0.218 sec)
# INFO:tensorflow:mrr: = 0.20280000000000004 (0.383 sec)
# INFO:tensorflow:mrr: = 0.16760000000000042 (0.175 sec)
# INFO:tensorflow:mrr: = 0.18920000000000028 (0.278 sec)
# INFO:tensorflow:mrr: = 0.2212000000000004 (0.258 sec)
# INFO:tensorflow:mrr: = 0.19640000000000027 (0.400 sec)
# INFO:tensorflow:mrr: = 0.23719999999999958 (0.195 sec)
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:mrr: = 0.20559999999999973 (0.211 sec)
# INFO:tensorflow:mrr: = 0.2844 (0.323 sec)
# INFO:tensorflow:mrr: = 0.2639999999999996 (0.180 sec)
# INFO:tensorflow:mrr: = 0.19480000000000008 (0.192 sec)
# INFO:tensorflow:mrr: = 0.2519999999999996 (0.194 sec)
# INFO:tensorflow:mrr: = 0.24600000000000063 (0.265 sec)
# INFO:tensorflow:mrr: = 0.24399999999999997 (0.368 sec)
# INFO:tensorflow:mrr: = 0.21999999999999992 (0.248 sec)
# INFO:tensorflow:mrr: = 0.17680000000000032 (0.183 sec)
# INFO:tensorflow:mrr: = 0.2928000000000009 (0.227 sec)
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:mrr: = 0.23639999999999972 (0.231 sec)
# INFO:tensorflow:mrr: = 0.23200000000000026 (0.224 sec)
# INFO:tensorflow:mrr: = 0.18319999999999992 (0.226 sec)
# INFO:tensorflow:mrr: = 0.19560000000000033 (0.209 sec)
# INFO:tensorflow:mrr: = 0.18559999999999963 (0.207 sec)
# INFO:tensorflow:mrr: = 0.11559999999999973 (0.237 sec)
# INFO:tensorflow:mrr: = 0.14993999999999955 (0.259 sec)
# INFO:tensorflow:mrr: = 0.2891999999999997 (0.329 sec)
# INFO:tensorflow:mrr: = 0.20960000000000029 (0.300 sec)
# INFO:tensorflow:mrr: = 0.1964 (0.312 sec)
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:mrr: = 0.17959999999999976 (0.193 sec)
# INFO:tensorflow:mrr: = 0.18640000000000087 (0.279 sec)
# INFO:tensorflow:mrr: = 0.3268000000000005 (0.303 sec)
# INFO:tensorflow:mrr: = 0.3003999999999996 (0.204 sec)
# INFO:tensorflow:mrr: = 0.19000000000000042 (0.274 sec)
# INFO:tensorflow:mrr: = 0.1803999999999998 (0.272 sec)
# INFO:tensorflow:mrr: = 0.2700000000000001 (0.160 sec)
# INFO:tensorflow:mrr: = 0.22559999999999997 (0.401 sec)
# INFO:tensorflow:mrr: = 0.2168000000000002 (0.268 sec)
# INFO:tensorflow:mrr: = 0.2244000000000004 (0.229 sec)
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:mrr: = 0.25039999999999907 (0.323 sec)
# INFO:tensorflow:mrr: = 0.15920000000000017 (0.317 sec)
# INFO:tensorflow:mrr: = 0.24080000000000032 (0.234 sec)
# INFO:tensorflow:mrr: = 0.2644 (0.292 sec)
# INFO:tensorflow:mrr: = 0.2728000000000007 (0.165 sec)
# INFO:tensorflow:mrr: = 0.23879999999999996 (0.257 sec)
# INFO:tensorflow:mrr: = 0.2132000000000002 (0.162 sec)
# INFO:tensorflow:mrr: = 0.18720000000000012 (0.232 sec)
# INFO:tensorflow:mrr: = 0.25040000000000057 (0.228 sec)
# INFO:tensorflow:mrr: = 0.190399999999999 (0.238 sec)
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:mrr: = 0.23560000000000028 (0.262 sec)
# INFO:tensorflow:mrr: = 0.2624000000000002 (0.139 sec)
# INFO:tensorflow:mrr: = 0.25800000000000056 (0.157 sec)
# INFO:tensorflow:mrr: = 0.2575999999999994 (0.192 sec)
# INFO:tensorflow:mrr: = 0.17120000000000013 (0.271 sec)
# INFO:tensorflow:mrr: = 0.25960000000000055 (0.203 sec)
# INFO:tensorflow:mrr: = 0.1691999999999999 (0.226 sec)
# INFO:tensorflow:mrr: = 0.16760000000000033 (0.179 sec)
# INFO:tensorflow:mrr: = 0.22159999999999982 (0.218 sec)
# INFO:tensorflow:mrr: = 0.1704000000000002 (0.170 sec)
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:mrr: = 0.22680000000000008 (0.195 sec)
# INFO:tensorflow:Finished evaluation at 2019-06-23-21:23:03
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.0295, global_step = 700, loss = 3.2558494
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 700: ./model_small_nn/model.ckpt-700
# INFO:tensorflow:global_step/sec: 0.660492
# INFO:tensorflow:loss = 3.2753482, step = 701 (30.280 sec)
# INFO:tensorflow:global_step/sec: 4.28904
# INFO:tensorflow:loss = 3.2553482, step = 721 (4.663 sec)
# INFO:tensorflow:global_step/sec: 4.04465
# INFO:tensorflow:loss = 3.2553482, step = 741 (4.945 sec)
# INFO:tensorflow:global_step/sec: 4.51644
# INFO:tensorflow:loss = 3.2453482, step = 761 (4.429 sec)
# INFO:tensorflow:global_step/sec: 4.04517
# INFO:tensorflow:loss = 3.2453482, step = 781 (4.944 sec)
# INFO:tensorflow:Saving checkpoints for 800 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T21:23:27Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:mrr: = 0.19999999999999993
# INFO:tensorflow:mrr: = 0.13920000000000005 (0.225 sec)
# INFO:tensorflow:mrr: = 0.2348000000000003 (0.173 sec)
# INFO:tensorflow:mrr: = 0.20599999999999946 (0.402 sec)
# INFO:tensorflow:mrr: = 0.25200000000000033 (0.349 sec)
# INFO:tensorflow:mrr: = 0.2304000000000001 (0.187 sec)
# INFO:tensorflow:mrr: = 0.23920000000000008 (0.472 sec)
# INFO:tensorflow:mrr: = 0.2196000000000009 (0.231 sec)
# INFO:tensorflow:mrr: = 0.1943999999999995 (0.216 sec)
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:mrr: = 0.2087999999999999 (0.183 sec)
# INFO:tensorflow:mrr: = 0.2312 (0.244 sec)
# INFO:tensorflow:mrr: = 0.14839999999999995 (0.181 sec)
# INFO:tensorflow:mrr: = 0.19840000000000016 (0.226 sec)
# INFO:tensorflow:mrr: = 0.11839999999999969 (0.199 sec)
# INFO:tensorflow:mrr: = 0.26279999999999987 (0.163 sec)
# INFO:tensorflow:mrr: = 0.25520000000000026 (0.209 sec)
# INFO:tensorflow:mrr: = 0.2079999999999999 (0.178 sec)
# INFO:tensorflow:mrr: = 0.19119999999999993 (0.168 sec)
# INFO:tensorflow:mrr: = 0.2832000000000006 (0.254 sec)
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:mrr: = 0.25120000000000053 (0.237 sec)
# INFO:tensorflow:mrr: = 0.20319999999999955 (0.181 sec)
# INFO:tensorflow:mrr: = 0.23000000000000073 (0.165 sec)
# INFO:tensorflow:mrr: = 0.2124000000000001 (0.217 sec)
# INFO:tensorflow:mrr: = 0.26840000000000047 (0.177 sec)
# INFO:tensorflow:mrr: = 0.18880000000000002 (0.223 sec)
# INFO:tensorflow:mrr: = 0.16080000000000008 (0.230 sec)
# INFO:tensorflow:mrr: = 0.2692000000000003 (0.186 sec)
# INFO:tensorflow:mrr: = 0.22960000000000064 (0.229 sec)
# INFO:tensorflow:mrr: = 0.22640000000000018 (0.224 sec)
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:mrr: = 0.2272000000000001 (0.187 sec)
# INFO:tensorflow:mrr: = 0.19599999999999965 (0.178 sec)
# INFO:tensorflow:mrr: = 0.14279999999999995 (0.263 sec)
# INFO:tensorflow:mrr: = 0.21959999999999977 (0.254 sec)
# INFO:tensorflow:mrr: = 0.25760000000000055 (0.264 sec)
# INFO:tensorflow:mrr: = 0.24480000000000018 (0.419 sec)
# INFO:tensorflow:mrr: = 0.2269440000000003 (0.417 sec)
# INFO:tensorflow:mrr: = 0.18640000000000018 (0.155 sec)
# INFO:tensorflow:mrr: = 0.19879999999999973 (0.234 sec)
# INFO:tensorflow:mrr: = 0.30880000000000074 (0.220 sec)
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:mrr: = 0.21600000000000036 (0.293 sec)
# INFO:tensorflow:mrr: = 0.1623999999999996 (0.176 sec)
# INFO:tensorflow:mrr: = 0.17360000000000006 (0.187 sec)
# INFO:tensorflow:mrr: = 0.1988000000000001 (0.212 sec)
# INFO:tensorflow:mrr: = 0.20280000000000004 (0.377 sec)
# INFO:tensorflow:mrr: = 0.16760000000000042 (0.169 sec)
# INFO:tensorflow:mrr: = 0.18920000000000028 (0.292 sec)
# INFO:tensorflow:mrr: = 0.2212000000000004 (0.264 sec)
# INFO:tensorflow:mrr: = 0.19640000000000027 (0.384 sec)
# INFO:tensorflow:mrr: = 0.23719999999999958 (0.183 sec)
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:mrr: = 0.20559999999999973 (0.199 sec)
# INFO:tensorflow:mrr: = 0.2844 (0.310 sec)
# INFO:tensorflow:mrr: = 0.2639999999999996 (0.177 sec)
# INFO:tensorflow:mrr: = 0.19480000000000008 (0.203 sec)
# INFO:tensorflow:mrr: = 0.2519999999999996 (0.201 sec)
# INFO:tensorflow:mrr: = 0.24600000000000063 (0.323 sec)
# INFO:tensorflow:mrr: = 0.24399999999999997 (0.339 sec)
# INFO:tensorflow:mrr: = 0.21999999999999992 (0.238 sec)
# INFO:tensorflow:mrr: = 0.17680000000000032 (0.178 sec)
# INFO:tensorflow:mrr: = 0.2928000000000009 (0.233 sec)
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:mrr: = 0.23639999999999972 (0.244 sec)
# INFO:tensorflow:mrr: = 0.23200000000000026 (0.223 sec)
# INFO:tensorflow:mrr: = 0.18319999999999992 (0.229 sec)
# INFO:tensorflow:mrr: = 0.19560000000000033 (0.205 sec)
# INFO:tensorflow:mrr: = 0.18559999999999963 (0.180 sec)
# INFO:tensorflow:mrr: = 0.11559999999999973 (0.246 sec)
# INFO:tensorflow:mrr: = 0.1498159999999996 (0.255 sec)
# INFO:tensorflow:mrr: = 0.2891999999999997 (0.314 sec)
# INFO:tensorflow:mrr: = 0.20960000000000029 (0.333 sec)
# INFO:tensorflow:mrr: = 0.1964 (0.320 sec)
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:mrr: = 0.17959999999999976 (0.194 sec)
# INFO:tensorflow:mrr: = 0.18640000000000087 (0.256 sec)
# INFO:tensorflow:mrr: = 0.3268000000000005 (0.277 sec)
# INFO:tensorflow:mrr: = 0.3003999999999996 (0.193 sec)
# INFO:tensorflow:mrr: = 0.19000000000000042 (0.269 sec)
# INFO:tensorflow:mrr: = 0.1803999999999998 (0.202 sec)
# INFO:tensorflow:mrr: = 0.2700000000000001 (0.141 sec)
# INFO:tensorflow:mrr: = 0.22559999999999997 (0.384 sec)
# INFO:tensorflow:mrr: = 0.2168000000000002 (0.275 sec)
# INFO:tensorflow:mrr: = 0.2244000000000004 (0.214 sec)
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:mrr: = 0.25039999999999907 (0.279 sec)
# INFO:tensorflow:mrr: = 0.15920000000000017 (0.263 sec)
# INFO:tensorflow:mrr: = 0.24080000000000032 (0.221 sec)
# INFO:tensorflow:mrr: = 0.2644 (0.282 sec)
# INFO:tensorflow:mrr: = 0.2728000000000007 (0.168 sec)
# INFO:tensorflow:mrr: = 0.23879999999999996 (0.240 sec)
# INFO:tensorflow:mrr: = 0.2132000000000002 (0.166 sec)
# INFO:tensorflow:mrr: = 0.18720000000000012 (0.247 sec)
# INFO:tensorflow:mrr: = 0.25040000000000057 (0.241 sec)
# INFO:tensorflow:mrr: = 0.190399999999999 (0.250 sec)
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:mrr: = 0.23560000000000028 (0.264 sec)
# INFO:tensorflow:mrr: = 0.2624000000000002 (0.171 sec)
# INFO:tensorflow:mrr: = 0.25800000000000056 (0.166 sec)
# INFO:tensorflow:mrr: = 0.2575999999999994 (0.209 sec)
# INFO:tensorflow:mrr: = 0.17120000000000013 (0.282 sec)
# INFO:tensorflow:mrr: = 0.25960000000000055 (0.223 sec)
# INFO:tensorflow:mrr: = 0.1691999999999999 (0.230 sec)
# INFO:tensorflow:mrr: = 0.16760000000000033 (0.209 sec)
# INFO:tensorflow:mrr: = 0.22159999999999982 (0.239 sec)
# INFO:tensorflow:mrr: = 0.1704000000000002 (0.186 sec)
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:mrr: = 0.22680000000000008 (0.235 sec)
# INFO:tensorflow:Finished evaluation at 2019-06-23-21:23:52
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.0295, global_step = 800, loss = 3.2558494
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: ./model_small_nn/model.ckpt-800
# INFO:tensorflow:global_step/sec: 0.6714
# INFO:tensorflow:loss = 3.2553482, step = 801 (29.789 sec)
# INFO:tensorflow:global_step/sec: 3.65068
# INFO:tensorflow:loss = 3.2353482, step = 821 (5.478 sec)
# INFO:tensorflow:global_step/sec: 4.0336
# INFO:tensorflow:loss = 3.2453482, step = 841 (4.959 sec)
# INFO:tensorflow:global_step/sec: 3.81084
# INFO:tensorflow:loss = 3.2853482, step = 861 (5.248 sec)
# INFO:tensorflow:global_step/sec: 4.2343
# INFO:tensorflow:loss = 3.2553482, step = 881 (4.723 sec)
# INFO:tensorflow:Saving checkpoints for 900 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T21:24:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:mrr: = 0.19999999999999993
# INFO:tensorflow:mrr: = 0.13920000000000005 (0.233 sec)
# INFO:tensorflow:mrr: = 0.2348000000000003 (0.190 sec)
# INFO:tensorflow:mrr: = 0.20599999999999946 (0.422 sec)
# INFO:tensorflow:mrr: = 0.25200000000000033 (0.379 sec)
# INFO:tensorflow:mrr: = 0.2304000000000001 (0.232 sec)
# INFO:tensorflow:mrr: = 0.23920000000000008 (0.522 sec)
# INFO:tensorflow:mrr: = 0.2196000000000009 (0.237 sec)
# INFO:tensorflow:mrr: = 0.1943999999999995 (0.241 sec)
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:mrr: = 0.2087999999999999 (0.222 sec)
# INFO:tensorflow:mrr: = 0.2312 (0.276 sec)
# INFO:tensorflow:mrr: = 0.14839999999999995 (0.195 sec)
# INFO:tensorflow:mrr: = 0.19840000000000016 (0.250 sec)
# INFO:tensorflow:mrr: = 0.11839999999999969 (0.213 sec)
# INFO:tensorflow:mrr: = 0.26279999999999987 (0.183 sec)
# INFO:tensorflow:mrr: = 0.25520000000000026 (0.226 sec)
# INFO:tensorflow:mrr: = 0.2079999999999999 (0.228 sec)
# INFO:tensorflow:mrr: = 0.19119999999999993 (0.183 sec)
# INFO:tensorflow:mrr: = 0.2832000000000006 (0.306 sec)
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:mrr: = 0.25120000000000053 (0.243 sec)
# INFO:tensorflow:mrr: = 0.20319999999999955 (0.187 sec)
# INFO:tensorflow:mrr: = 0.23000000000000073 (0.200 sec)
# INFO:tensorflow:mrr: = 0.2124000000000001 (0.237 sec)
# INFO:tensorflow:mrr: = 0.26840000000000047 (0.212 sec)
# INFO:tensorflow:mrr: = 0.18880000000000002 (0.276 sec)
# INFO:tensorflow:mrr: = 0.16080000000000008 (0.241 sec)
# INFO:tensorflow:mrr: = 0.2692000000000003 (0.194 sec)
# INFO:tensorflow:mrr: = 0.22960000000000064 (0.282 sec)
# INFO:tensorflow:mrr: = 0.22640000000000018 (0.250 sec)
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:mrr: = 0.2272000000000001 (0.227 sec)
# INFO:tensorflow:mrr: = 0.19599999999999965 (0.182 sec)
# INFO:tensorflow:mrr: = 0.14279999999999995 (0.282 sec)
# INFO:tensorflow:mrr: = 0.21959999999999977 (0.264 sec)
# INFO:tensorflow:mrr: = 0.25760000000000055 (0.284 sec)
# INFO:tensorflow:mrr: = 0.24480000000000018 (0.427 sec)
# INFO:tensorflow:mrr: = 0.2269440000000003 (0.395 sec)
# INFO:tensorflow:mrr: = 0.18640000000000018 (0.177 sec)
# INFO:tensorflow:mrr: = 0.19879999999999973 (0.249 sec)
# INFO:tensorflow:mrr: = 0.30880000000000074 (0.228 sec)
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:mrr: = 0.21600000000000036 (0.360 sec)
# INFO:tensorflow:mrr: = 0.1623999999999996 (0.182 sec)
# INFO:tensorflow:mrr: = 0.17360000000000006 (0.210 sec)
# INFO:tensorflow:mrr: = 0.1988000000000001 (0.234 sec)
# INFO:tensorflow:mrr: = 0.20280000000000004 (0.439 sec)
# INFO:tensorflow:mrr: = 0.16760000000000042 (0.183 sec)
# INFO:tensorflow:mrr: = 0.18920000000000028 (0.296 sec)
# INFO:tensorflow:mrr: = 0.2212000000000004 (0.323 sec)
# INFO:tensorflow:mrr: = 0.19640000000000027 (0.424 sec)
# INFO:tensorflow:mrr: = 0.23719999999999958 (0.232 sec)
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:mrr: = 0.20559999999999973 (0.227 sec)
# INFO:tensorflow:mrr: = 0.2844 (0.317 sec)
# INFO:tensorflow:mrr: = 0.2639999999999996 (0.212 sec)
# INFO:tensorflow:mrr: = 0.19480000000000008 (0.206 sec)
# INFO:tensorflow:mrr: = 0.2519999999999996 (0.198 sec)
# INFO:tensorflow:mrr: = 0.24600000000000063 (0.287 sec)
# INFO:tensorflow:mrr: = 0.24399999999999997 (0.357 sec)
# INFO:tensorflow:mrr: = 0.21999999999999992 (0.251 sec)
# INFO:tensorflow:mrr: = 0.17680000000000032 (0.183 sec)
# INFO:tensorflow:mrr: = 0.2928000000000009 (0.250 sec)
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:mrr: = 0.23639999999999972 (0.245 sec)
# INFO:tensorflow:mrr: = 0.23200000000000026 (0.254 sec)
# INFO:tensorflow:mrr: = 0.18319999999999992 (0.246 sec)
# INFO:tensorflow:mrr: = 0.19560000000000033 (0.223 sec)
# INFO:tensorflow:mrr: = 0.18559999999999963 (0.205 sec)
# INFO:tensorflow:mrr: = 0.11559999999999973 (0.301 sec)
# INFO:tensorflow:mrr: = 0.1498159999999996 (0.258 sec)
# INFO:tensorflow:mrr: = 0.2891999999999997 (0.342 sec)
# INFO:tensorflow:mrr: = 0.20960000000000029 (0.321 sec)
# INFO:tensorflow:mrr: = 0.1964 (0.294 sec)
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:mrr: = 0.17959999999999976 (0.199 sec)
# INFO:tensorflow:mrr: = 0.18640000000000087 (0.252 sec)
# INFO:tensorflow:mrr: = 0.3268000000000005 (0.305 sec)
# INFO:tensorflow:mrr: = 0.3003999999999996 (0.228 sec)
# INFO:tensorflow:mrr: = 0.19000000000000042 (0.299 sec)
# INFO:tensorflow:mrr: = 0.1803999999999998 (0.219 sec)
# INFO:tensorflow:mrr: = 0.2700000000000001 (0.158 sec)
# INFO:tensorflow:mrr: = 0.22559999999999997 (0.392 sec)
# INFO:tensorflow:mrr: = 0.2168000000000002 (0.262 sec)
# INFO:tensorflow:mrr: = 0.2244000000000004 (0.214 sec)
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:mrr: = 0.25039999999999907 (0.269 sec)
# INFO:tensorflow:mrr: = 0.15920000000000017 (0.255 sec)
# INFO:tensorflow:mrr: = 0.24080000000000032 (0.209 sec)
# INFO:tensorflow:mrr: = 0.2644 (0.297 sec)
# INFO:tensorflow:mrr: = 0.2728000000000007 (0.203 sec)
# INFO:tensorflow:mrr: = 0.23879999999999996 (0.273 sec)
# INFO:tensorflow:mrr: = 0.2132000000000002 (0.166 sec)
# INFO:tensorflow:mrr: = 0.18720000000000012 (0.239 sec)
# INFO:tensorflow:mrr: = 0.25040000000000057 (0.246 sec)
# INFO:tensorflow:mrr: = 0.190399999999999 (0.261 sec)
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:mrr: = 0.23560000000000028 (0.290 sec)
# INFO:tensorflow:mrr: = 0.2624000000000002 (0.157 sec)
# INFO:tensorflow:mrr: = 0.25800000000000056 (0.168 sec)
# INFO:tensorflow:mrr: = 0.2575999999999994 (0.223 sec)
# INFO:tensorflow:mrr: = 0.17120000000000013 (0.314 sec)
# INFO:tensorflow:mrr: = 0.25960000000000055 (0.255 sec)
# INFO:tensorflow:mrr: = 0.1691999999999999 (0.279 sec)
# INFO:tensorflow:mrr: = 0.16760000000000033 (0.227 sec)
# INFO:tensorflow:mrr: = 0.22159999999999982 (0.266 sec)
# INFO:tensorflow:mrr: = 0.1704000000000002 (0.203 sec)
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:mrr: = 0.22680000000000008 (0.218 sec)
# INFO:tensorflow:Finished evaluation at 2019-06-23-21:24:44
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.0295, global_step = 900, loss = 3.2558494
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 900: ./model_small_nn/model.ckpt-900
# INFO:tensorflow:global_step/sec: 0.61968
# INFO:tensorflow:loss = 3.2753482, step = 901 (32.275 sec)
# INFO:tensorflow:global_step/sec: 3.89109
# INFO:tensorflow:loss = 3.2353482, step = 921 (5.140 sec)
# INFO:tensorflow:global_step/sec: 4.13119
# INFO:tensorflow:loss = 3.2753482, step = 941 (4.841 sec)
# INFO:tensorflow:global_step/sec: 4.12413
# INFO:tensorflow:loss = 3.2753482, step = 961 (4.850 sec)
# INFO:tensorflow:global_step/sec: 3.80928
# INFO:tensorflow:loss = 3.2353482, step = 981 (5.251 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T21:25:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:mrr: = 0.19999999999999993
# INFO:tensorflow:mrr: = 0.13920000000000005 (0.239 sec)
# INFO:tensorflow:mrr: = 0.2348000000000003 (0.190 sec)
# INFO:tensorflow:mrr: = 0.20599999999999946 (0.430 sec)
# INFO:tensorflow:mrr: = 0.25200000000000033 (0.349 sec)
# INFO:tensorflow:mrr: = 0.2304000000000001 (0.220 sec)
# INFO:tensorflow:mrr: = 0.23920000000000008 (0.514 sec)
# INFO:tensorflow:mrr: = 0.2196000000000009 (0.291 sec)
# INFO:tensorflow:mrr: = 0.1943999999999995 (0.254 sec)
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:mrr: = 0.2087999999999999 (0.203 sec)
# INFO:tensorflow:mrr: = 0.2312 (0.259 sec)
# INFO:tensorflow:mrr: = 0.14839999999999995 (0.220 sec)
# INFO:tensorflow:mrr: = 0.19840000000000016 (0.261 sec)
# INFO:tensorflow:mrr: = 0.11839999999999969 (0.211 sec)
# INFO:tensorflow:mrr: = 0.26279999999999987 (0.150 sec)
# INFO:tensorflow:mrr: = 0.25520000000000026 (0.221 sec)
# INFO:tensorflow:mrr: = 0.2079999999999999 (0.193 sec)
# INFO:tensorflow:mrr: = 0.19119999999999993 (0.182 sec)
# INFO:tensorflow:mrr: = 0.2832000000000006 (0.275 sec)
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:mrr: = 0.25120000000000053 (0.234 sec)
# INFO:tensorflow:mrr: = 0.20319999999999955 (0.180 sec)
# INFO:tensorflow:mrr: = 0.23000000000000073 (0.171 sec)
# INFO:tensorflow:mrr: = 0.2124000000000001 (0.230 sec)
# INFO:tensorflow:mrr: = 0.26840000000000047 (0.225 sec)
# INFO:tensorflow:mrr: = 0.18880000000000002 (0.267 sec)
# INFO:tensorflow:mrr: = 0.16080000000000008 (0.241 sec)
# INFO:tensorflow:mrr: = 0.2692000000000003 (0.193 sec)
# INFO:tensorflow:mrr: = 0.22960000000000064 (0.252 sec)
# INFO:tensorflow:mrr: = 0.22640000000000018 (0.275 sec)
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:mrr: = 0.2272000000000001 (0.218 sec)
# INFO:tensorflow:mrr: = 0.19599999999999965 (0.190 sec)
# INFO:tensorflow:mrr: = 0.14279999999999995 (0.288 sec)
# INFO:tensorflow:mrr: = 0.21959999999999977 (0.280 sec)
# INFO:tensorflow:mrr: = 0.25760000000000055 (0.276 sec)
# INFO:tensorflow:mrr: = 0.24480000000000018 (0.442 sec)
# INFO:tensorflow:mrr: = 0.2269440000000003 (0.371 sec)
# INFO:tensorflow:mrr: = 0.18640000000000018 (0.162 sec)
# INFO:tensorflow:mrr: = 0.19879999999999973 (0.294 sec)
# INFO:tensorflow:mrr: = 0.30880000000000074 (0.293 sec)
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:mrr: = 0.21600000000000036 (0.390 sec)
# INFO:tensorflow:mrr: = 0.1623999999999996 (0.251 sec)
# INFO:tensorflow:mrr: = 0.17360000000000006 (0.265 sec)
# INFO:tensorflow:mrr: = 0.1988000000000001 (0.269 sec)
# INFO:tensorflow:mrr: = 0.20280000000000004 (0.504 sec)
# INFO:tensorflow:mrr: = 0.16760000000000042 (0.229 sec)
# INFO:tensorflow:mrr: = 0.18920000000000028 (0.360 sec)
# INFO:tensorflow:mrr: = 0.2212000000000004 (0.367 sec)
# INFO:tensorflow:mrr: = 0.19640000000000027 (0.501 sec)
# INFO:tensorflow:mrr: = 0.23719999999999958 (0.264 sec)
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:mrr: = 0.20559999999999973 (0.261 sec)
# INFO:tensorflow:mrr: = 0.2844 (0.411 sec)
# INFO:tensorflow:mrr: = 0.2639999999999996 (0.228 sec)
# INFO:tensorflow:mrr: = 0.19480000000000008 (0.379 sec)
# INFO:tensorflow:mrr: = 0.2519999999999996 (0.702 sec)
# INFO:tensorflow:mrr: = 0.24600000000000063 (1.181 sec)
# INFO:tensorflow:mrr: = 0.24399999999999997 (1.584 sec)
# INFO:tensorflow:mrr: = 0.21999999999999992 (1.059 sec)
# INFO:tensorflow:mrr: = 0.17680000000000032 (0.751 sec)
# INFO:tensorflow:mrr: = 0.2928000000000009 (1.059 sec)
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:mrr: = 0.23639999999999972 (0.606 sec)
# INFO:tensorflow:mrr: = 0.23200000000000026 (0.299 sec)
# INFO:tensorflow:mrr: = 0.18319999999999992 (0.277 sec)
# INFO:tensorflow:mrr: = 0.19560000000000033 (0.262 sec)
# INFO:tensorflow:mrr: = 0.18559999999999963 (0.200 sec)
# INFO:tensorflow:mrr: = 0.11559999999999973 (0.268 sec)
# INFO:tensorflow:mrr: = 0.1498159999999996 (0.256 sec)
# INFO:tensorflow:mrr: = 0.2891999999999997 (0.321 sec)
# INFO:tensorflow:mrr: = 0.20960000000000029 (0.297 sec)
# INFO:tensorflow:mrr: = 0.1964 (0.304 sec)
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:mrr: = 0.17959999999999976 (0.203 sec)
# INFO:tensorflow:mrr: = 0.18640000000000087 (0.255 sec)
# INFO:tensorflow:mrr: = 0.3268000000000005 (0.327 sec)
# INFO:tensorflow:mrr: = 0.3003999999999996 (0.221 sec)
# INFO:tensorflow:mrr: = 0.19000000000000042 (0.281 sec)
# INFO:tensorflow:mrr: = 0.1803999999999998 (0.208 sec)
# INFO:tensorflow:mrr: = 0.2700000000000001 (0.150 sec)
# INFO:tensorflow:mrr: = 0.22559999999999997 (0.384 sec)
# INFO:tensorflow:mrr: = 0.2168000000000002 (0.244 sec)
# INFO:tensorflow:mrr: = 0.2244000000000004 (0.214 sec)
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:mrr: = 0.25039999999999907 (0.290 sec)
# INFO:tensorflow:mrr: = 0.15920000000000017 (0.256 sec)
# INFO:tensorflow:mrr: = 0.24080000000000032 (0.235 sec)
# INFO:tensorflow:mrr: = 0.2644 (0.343 sec)
# INFO:tensorflow:mrr: = 0.2728000000000007 (0.201 sec)
# INFO:tensorflow:mrr: = 0.23879999999999996 (0.261 sec)
# INFO:tensorflow:mrr: = 0.2132000000000002 (0.172 sec)
# INFO:tensorflow:mrr: = 0.18720000000000012 (0.236 sec)
# INFO:tensorflow:mrr: = 0.25040000000000057 (0.258 sec)
# INFO:tensorflow:mrr: = 0.190399999999999 (0.262 sec)
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:mrr: = 0.23560000000000028 (0.275 sec)
# INFO:tensorflow:mrr: = 0.2624000000000002 (0.167 sec)
# INFO:tensorflow:mrr: = 0.25800000000000056 (0.189 sec)
# INFO:tensorflow:mrr: = 0.2575999999999994 (0.213 sec)
# INFO:tensorflow:mrr: = 0.17120000000000013 (0.286 sec)
# INFO:tensorflow:mrr: = 0.25960000000000055 (0.206 sec)
# INFO:tensorflow:mrr: = 0.1691999999999999 (0.279 sec)
# INFO:tensorflow:mrr: = 0.16760000000000033 (0.194 sec)
# INFO:tensorflow:mrr: = 0.22159999999999982 (0.237 sec)
# INFO:tensorflow:mrr: = 0.1704000000000002 (0.213 sec)
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:mrr: = 0.22680000000000008 (0.240 sec)
# INFO:tensorflow:Finished evaluation at 2019-06-23-21:25:42
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.0295, global_step = 1000, loss = 3.2558494
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./model_small_nn/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 0.525873
# INFO:tensorflow:loss = 3.2553482, step = 1001 (38.032 sec)
# INFO:tensorflow:global_step/sec: 4.05269
# INFO:tensorflow:loss = 3.2753482, step = 1021 (4.935 sec)
# INFO:tensorflow:global_step/sec: 4.23508
# INFO:tensorflow:loss = 3.2453482, step = 1041 (4.723 sec)
# INFO:tensorflow:global_step/sec: 3.92579
# INFO:tensorflow:loss = 3.2453482, step = 1061 (5.094 sec)
# INFO:tensorflow:global_step/sec: 3.98935
# INFO:tensorflow:loss = 3.2653482, step = 1081 (5.013 sec)
# INFO:tensorflow:Saving checkpoints for 1100 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T21:26:07Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:mrr: = 0.19999999999999993
# INFO:tensorflow:mrr: = 0.13920000000000005 (0.206 sec)
# INFO:tensorflow:mrr: = 0.2348000000000003 (0.164 sec)
# INFO:tensorflow:mrr: = 0.20599999999999946 (0.375 sec)
# INFO:tensorflow:mrr: = 0.25200000000000033 (0.327 sec)
# INFO:tensorflow:mrr: = 0.2304000000000001 (0.194 sec)
# INFO:tensorflow:mrr: = 0.23920000000000008 (0.453 sec)
# INFO:tensorflow:mrr: = 0.2196000000000009 (0.237 sec)
# INFO:tensorflow:mrr: = 0.1943999999999995 (0.213 sec)
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:mrr: = 0.2087999999999999 (0.195 sec)
# INFO:tensorflow:mrr: = 0.2312 (0.242 sec)
# INFO:tensorflow:mrr: = 0.14839999999999995 (0.184 sec)
# INFO:tensorflow:mrr: = 0.19840000000000016 (0.231 sec)
# INFO:tensorflow:mrr: = 0.11839999999999969 (0.219 sec)
# INFO:tensorflow:mrr: = 0.26279999999999987 (0.153 sec)
# INFO:tensorflow:mrr: = 0.25520000000000026 (0.207 sec)
# INFO:tensorflow:mrr: = 0.2079999999999999 (0.174 sec)
# INFO:tensorflow:mrr: = 0.19119999999999993 (0.183 sec)
# INFO:tensorflow:mrr: = 0.2832000000000006 (0.254 sec)
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:mrr: = 0.25120000000000053 (0.244 sec)
# INFO:tensorflow:mrr: = 0.20319999999999955 (0.212 sec)
# INFO:tensorflow:mrr: = 0.23000000000000073 (0.208 sec)
# INFO:tensorflow:mrr: = 0.2124000000000001 (0.294 sec)
# INFO:tensorflow:mrr: = 0.26840000000000047 (0.193 sec)
# INFO:tensorflow:mrr: = 0.18880000000000002 (0.239 sec)
# INFO:tensorflow:mrr: = 0.16080000000000008 (0.233 sec)
# INFO:tensorflow:mrr: = 0.2692000000000003 (0.200 sec)
# INFO:tensorflow:mrr: = 0.22960000000000064 (0.223 sec)
# INFO:tensorflow:mrr: = 0.22640000000000018 (0.230 sec)
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:mrr: = 0.2272000000000001 (0.207 sec)
# INFO:tensorflow:mrr: = 0.19599999999999965 (0.177 sec)
# INFO:tensorflow:mrr: = 0.14279999999999995 (0.253 sec)
# INFO:tensorflow:mrr: = 0.21959999999999977 (0.270 sec)
# INFO:tensorflow:mrr: = 0.25760000000000055 (0.277 sec)
# INFO:tensorflow:mrr: = 0.24480000000000018 (0.393 sec)
# INFO:tensorflow:mrr: = 0.2269440000000003 (0.369 sec)
# INFO:tensorflow:mrr: = 0.18640000000000018 (0.158 sec)
# INFO:tensorflow:mrr: = 0.19879999999999973 (0.245 sec)
# INFO:tensorflow:mrr: = 0.30880000000000074 (0.213 sec)
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:mrr: = 0.21600000000000036 (0.290 sec)
# INFO:tensorflow:mrr: = 0.1623999999999996 (0.174 sec)
# INFO:tensorflow:mrr: = 0.17360000000000006 (0.199 sec)
# INFO:tensorflow:mrr: = 0.1988000000000001 (0.220 sec)
# INFO:tensorflow:mrr: = 0.20280000000000004 (0.391 sec)
# INFO:tensorflow:mrr: = 0.16760000000000042 (0.179 sec)
# INFO:tensorflow:mrr: = 0.18920000000000028 (0.275 sec)
# INFO:tensorflow:mrr: = 0.2212000000000004 (0.284 sec)
# INFO:tensorflow:mrr: = 0.19640000000000027 (0.400 sec)
# INFO:tensorflow:mrr: = 0.23719999999999958 (0.193 sec)
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:mrr: = 0.20559999999999973 (0.202 sec)
# INFO:tensorflow:mrr: = 0.2844 (0.332 sec)
# INFO:tensorflow:mrr: = 0.2639999999999996 (0.214 sec)
# INFO:tensorflow:mrr: = 0.19480000000000008 (0.201 sec)
# INFO:tensorflow:mrr: = 0.2519999999999996 (0.196 sec)
# INFO:tensorflow:mrr: = 0.24600000000000063 (0.285 sec)
# INFO:tensorflow:mrr: = 0.24399999999999997 (0.372 sec)
# INFO:tensorflow:mrr: = 0.21999999999999992 (0.258 sec)
# INFO:tensorflow:mrr: = 0.17680000000000032 (0.173 sec)
# INFO:tensorflow:mrr: = 0.2928000000000009 (0.234 sec)
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:mrr: = 0.23639999999999972 (0.245 sec)
# INFO:tensorflow:mrr: = 0.23200000000000026 (0.222 sec)
# INFO:tensorflow:mrr: = 0.18319999999999992 (0.240 sec)
# INFO:tensorflow:mrr: = 0.19560000000000033 (0.216 sec)
# INFO:tensorflow:mrr: = 0.18559999999999963 (0.209 sec)
# INFO:tensorflow:mrr: = 0.11559999999999973 (0.262 sec)
# INFO:tensorflow:mrr: = 0.1498159999999996 (0.290 sec)
# INFO:tensorflow:mrr: = 0.2891999999999997 (0.324 sec)
# INFO:tensorflow:mrr: = 0.20960000000000029 (0.298 sec)
# INFO:tensorflow:mrr: = 0.1964 (0.310 sec)
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:mrr: = 0.17959999999999976 (0.185 sec)
# INFO:tensorflow:mrr: = 0.18640000000000087 (0.245 sec)
# INFO:tensorflow:mrr: = 0.3268000000000005 (0.337 sec)
# INFO:tensorflow:mrr: = 0.3003999999999996 (0.209 sec)
# INFO:tensorflow:mrr: = 0.19000000000000042 (0.287 sec)
# INFO:tensorflow:mrr: = 0.1803999999999998 (0.197 sec)
# INFO:tensorflow:mrr: = 0.2700000000000001 (0.144 sec)
# INFO:tensorflow:mrr: = 0.22559999999999997 (0.386 sec)
# INFO:tensorflow:mrr: = 0.2168000000000002 (0.258 sec)
# INFO:tensorflow:mrr: = 0.2244000000000004 (0.216 sec)
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:mrr: = 0.25039999999999907 (0.284 sec)
# INFO:tensorflow:mrr: = 0.15920000000000017 (0.241 sec)
# INFO:tensorflow:mrr: = 0.24080000000000032 (0.201 sec)
# INFO:tensorflow:mrr: = 0.2644 (0.289 sec)
# INFO:tensorflow:mrr: = 0.2728000000000007 (0.167 sec)
# INFO:tensorflow:mrr: = 0.23879999999999996 (0.259 sec)
# INFO:tensorflow:mrr: = 0.2132000000000002 (0.150 sec)
# INFO:tensorflow:mrr: = 0.18720000000000012 (0.244 sec)
# INFO:tensorflow:mrr: = 0.25040000000000057 (0.234 sec)
# INFO:tensorflow:mrr: = 0.190399999999999 (0.246 sec)
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:mrr: = 0.23560000000000028 (0.271 sec)
# INFO:tensorflow:mrr: = 0.2624000000000002 (0.154 sec)
# INFO:tensorflow:mrr: = 0.25800000000000056 (0.162 sec)
# INFO:tensorflow:mrr: = 0.2575999999999994 (0.226 sec)
# INFO:tensorflow:mrr: = 0.17120000000000013 (0.306 sec)
# INFO:tensorflow:mrr: = 0.25960000000000055 (0.217 sec)
# INFO:tensorflow:mrr: = 0.1691999999999999 (0.238 sec)
# INFO:tensorflow:mrr: = 0.16760000000000033 (0.183 sec)
# INFO:tensorflow:mrr: = 0.22159999999999982 (0.228 sec)
# INFO:tensorflow:mrr: = 0.1704000000000002 (0.186 sec)
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:mrr: = 0.22680000000000008 (0.213 sec)
# INFO:tensorflow:Finished evaluation at 2019-06-23-21:26:32
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.0295, global_step = 1100, loss = 3.2558494
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1100: ./model_small_nn/model.ckpt-1100
# INFO:tensorflow:global_step/sec: 0.666551
# INFO:tensorflow:loss = 3.2353482, step = 1101 (30.006 sec)
# INFO:tensorflow:global_step/sec: 3.707
# INFO:tensorflow:loss = 3.2653482, step = 1121 (5.394 sec)
# INFO:tensorflow:global_step/sec: 3.76487
# INFO:tensorflow:loss = 3.2853482, step = 1141 (5.313 sec)
# INFO:tensorflow:global_step/sec: 4.30682
# INFO:tensorflow:loss = 3.2453482, step = 1161 (4.644 sec)
# INFO:tensorflow:global_step/sec: 4.23611
# INFO:tensorflow:loss = 3.2653482, step = 1181 (4.722 sec)
# INFO:tensorflow:Saving checkpoints for 1200 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T21:26:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:mrr: = 0.19999999999999993
# INFO:tensorflow:mrr: = 0.13920000000000005 (0.213 sec)
# INFO:tensorflow:mrr: = 0.2348000000000003 (0.180 sec)
# INFO:tensorflow:mrr: = 0.20599999999999946 (0.398 sec)
# INFO:tensorflow:mrr: = 0.25200000000000033 (0.336 sec)
# INFO:tensorflow:mrr: = 0.2304000000000001 (0.199 sec)
# INFO:tensorflow:mrr: = 0.23920000000000008 (0.484 sec)
# INFO:tensorflow:mrr: = 0.2196000000000009 (0.233 sec)
# INFO:tensorflow:mrr: = 0.1943999999999995 (0.217 sec)
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:mrr: = 0.2087999999999999 (0.215 sec)
# INFO:tensorflow:mrr: = 0.2312 (0.240 sec)
# INFO:tensorflow:mrr: = 0.14839999999999995 (0.188 sec)
# INFO:tensorflow:mrr: = 0.19840000000000016 (0.243 sec)
# INFO:tensorflow:mrr: = 0.11839999999999969 (0.207 sec)
# INFO:tensorflow:mrr: = 0.26279999999999987 (0.148 sec)
# INFO:tensorflow:mrr: = 0.25520000000000026 (0.213 sec)
# INFO:tensorflow:mrr: = 0.2079999999999999 (0.172 sec)
# INFO:tensorflow:mrr: = 0.19119999999999993 (0.161 sec)
# INFO:tensorflow:mrr: = 0.2832000000000006 (0.265 sec)
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:mrr: = 0.25120000000000053 (0.233 sec)
# INFO:tensorflow:mrr: = 0.20319999999999955 (0.187 sec)
# INFO:tensorflow:mrr: = 0.23000000000000073 (0.184 sec)
# INFO:tensorflow:mrr: = 0.2124000000000001 (0.209 sec)
# INFO:tensorflow:mrr: = 0.26840000000000047 (0.174 sec)
# INFO:tensorflow:mrr: = 0.18880000000000002 (0.237 sec)
# INFO:tensorflow:mrr: = 0.16080000000000008 (0.224 sec)
# INFO:tensorflow:mrr: = 0.2692000000000003 (0.195 sec)
# INFO:tensorflow:mrr: = 0.22960000000000064 (0.223 sec)
# INFO:tensorflow:mrr: = 0.22640000000000018 (0.232 sec)
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:mrr: = 0.2272000000000001 (0.227 sec)
# INFO:tensorflow:mrr: = 0.19599999999999965 (0.212 sec)
# INFO:tensorflow:mrr: = 0.14279999999999995 (0.277 sec)
# INFO:tensorflow:mrr: = 0.21959999999999977 (0.237 sec)
# INFO:tensorflow:mrr: = 0.25760000000000055 (0.255 sec)
# INFO:tensorflow:mrr: = 0.24480000000000018 (0.398 sec)
# INFO:tensorflow:mrr: = 0.2269440000000003 (0.342 sec)
# INFO:tensorflow:mrr: = 0.18640000000000018 (0.153 sec)
# INFO:tensorflow:mrr: = 0.19879999999999973 (0.227 sec)
# INFO:tensorflow:mrr: = 0.30880000000000074 (0.209 sec)
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:mrr: = 0.21600000000000036 (0.281 sec)
# INFO:tensorflow:mrr: = 0.1623999999999996 (0.173 sec)
# INFO:tensorflow:mrr: = 0.17360000000000006 (0.193 sec)
# INFO:tensorflow:mrr: = 0.1988000000000001 (0.210 sec)
# INFO:tensorflow:mrr: = 0.20280000000000004 (0.353 sec)
# INFO:tensorflow:mrr: = 0.16760000000000042 (0.166 sec)
# INFO:tensorflow:mrr: = 0.18920000000000028 (0.283 sec)
# INFO:tensorflow:mrr: = 0.2212000000000004 (0.258 sec)
# INFO:tensorflow:mrr: = 0.19640000000000027 (0.369 sec)
# INFO:tensorflow:mrr: = 0.23719999999999958 (0.203 sec)
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:mrr: = 0.20559999999999973 (0.218 sec)
# INFO:tensorflow:mrr: = 0.2844 (0.313 sec)
# INFO:tensorflow:mrr: = 0.2639999999999996 (0.183 sec)
# INFO:tensorflow:mrr: = 0.19480000000000008 (0.202 sec)
# INFO:tensorflow:mrr: = 0.2519999999999996 (0.187 sec)
# INFO:tensorflow:mrr: = 0.24600000000000063 (0.263 sec)
# INFO:tensorflow:mrr: = 0.24399999999999997 (0.362 sec)
# INFO:tensorflow:mrr: = 0.21999999999999992 (0.249 sec)
# INFO:tensorflow:mrr: = 0.17680000000000032 (0.185 sec)
# INFO:tensorflow:mrr: = 0.2928000000000009 (0.261 sec)
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:mrr: = 0.23639999999999972 (0.277 sec)
# INFO:tensorflow:mrr: = 0.23200000000000026 (0.222 sec)
# INFO:tensorflow:mrr: = 0.18319999999999992 (0.243 sec)
# INFO:tensorflow:mrr: = 0.19560000000000033 (0.234 sec)
# INFO:tensorflow:mrr: = 0.18559999999999963 (0.207 sec)
# INFO:tensorflow:mrr: = 0.11559999999999973 (0.242 sec)
# INFO:tensorflow:mrr: = 0.1498159999999996 (0.260 sec)
# INFO:tensorflow:mrr: = 0.2891999999999997 (0.332 sec)
# INFO:tensorflow:mrr: = 0.20960000000000029 (0.312 sec)
# INFO:tensorflow:mrr: = 0.1964 (0.335 sec)
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:mrr: = 0.17959999999999976 (0.225 sec)
# INFO:tensorflow:mrr: = 0.18640000000000087 (0.294 sec)
# INFO:tensorflow:mrr: = 0.3268000000000005 (0.321 sec)
# INFO:tensorflow:mrr: = 0.3003999999999996 (0.207 sec)
# INFO:tensorflow:mrr: = 0.19000000000000042 (0.310 sec)
# INFO:tensorflow:mrr: = 0.1803999999999998 (0.235 sec)
# INFO:tensorflow:mrr: = 0.2700000000000001 (0.154 sec)
# INFO:tensorflow:mrr: = 0.22559999999999997 (0.366 sec)
# INFO:tensorflow:mrr: = 0.2168000000000002 (0.260 sec)
# INFO:tensorflow:mrr: = 0.2244000000000004 (0.218 sec)
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:mrr: = 0.25039999999999907 (0.286 sec)
# INFO:tensorflow:mrr: = 0.15920000000000017 (0.280 sec)
# INFO:tensorflow:mrr: = 0.24080000000000032 (0.205 sec)
# INFO:tensorflow:mrr: = 0.2644 (0.295 sec)
# INFO:tensorflow:mrr: = 0.2728000000000007 (0.199 sec)
# INFO:tensorflow:mrr: = 0.23879999999999996 (0.268 sec)
# INFO:tensorflow:mrr: = 0.2132000000000002 (0.168 sec)
# INFO:tensorflow:mrr: = 0.18720000000000012 (0.247 sec)
# INFO:tensorflow:mrr: = 0.25040000000000057 (0.230 sec)
# INFO:tensorflow:mrr: = 0.190399999999999 (0.254 sec)
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:mrr: = 0.23560000000000028 (0.265 sec)
# INFO:tensorflow:mrr: = 0.2624000000000002 (0.158 sec)
# INFO:tensorflow:mrr: = 0.25800000000000056 (0.188 sec)
# INFO:tensorflow:mrr: = 0.2575999999999994 (0.206 sec)
# INFO:tensorflow:mrr: = 0.17120000000000013 (0.295 sec)
# INFO:tensorflow:mrr: = 0.25960000000000055 (0.224 sec)
# INFO:tensorflow:mrr: = 0.1691999999999999 (0.235 sec)
# INFO:tensorflow:mrr: = 0.16760000000000033 (0.185 sec)
# INFO:tensorflow:mrr: = 0.22159999999999982 (0.215 sec)
# INFO:tensorflow:mrr: = 0.1704000000000002 (0.180 sec)
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:mrr: = 0.22680000000000008 (0.209 sec)
# INFO:tensorflow:Finished evaluation at 2019-06-23-21:27:23
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.0295, global_step = 1200, loss = 3.2558494
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: ./model_small_nn/model.ckpt-1200
# INFO:tensorflow:global_step/sec: 0.660612
# INFO:tensorflow:loss = 3.2653482, step = 1201 (30.275 sec)
# INFO:tensorflow:global_step/sec: 4.25575
# INFO:tensorflow:loss = 3.2653482, step = 1221 (4.699 sec)
# INFO:tensorflow:global_step/sec: 4.05977
# INFO:tensorflow:loss = 3.2853482, step = 1241 (4.927 sec)
# INFO:tensorflow:global_step/sec: 4.66712
# INFO:tensorflow:loss = 3.2553482, step = 1261 (4.285 sec)
# INFO:tensorflow:global_step/sec: 4.10551
# INFO:tensorflow:loss = 3.2453482, step = 1281 (4.872 sec)
# INFO:tensorflow:Saving checkpoints for 1300 into ./model_small_nn/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-23T21:27:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model_small_nn/model.ckpt-1300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:mrr: = 0.19999999999999993
# INFO:tensorflow:mrr: = 0.13920000000000005 (0.278 sec)
# INFO:tensorflow:mrr: = 0.2348000000000003 (0.224 sec)
# INFO:tensorflow:mrr: = 0.20599999999999946 (0.565 sec)
# INFO:tensorflow:mrr: = 0.25200000000000033 (0.405 sec)
# INFO:tensorflow:mrr: = 0.2304000000000001 (0.212 sec)
# INFO:tensorflow:mrr: = 0.23920000000000008 (0.510 sec)
# INFO:tensorflow:mrr: = 0.2196000000000009 (0.251 sec)
# INFO:tensorflow:mrr: = 0.1943999999999995 (0.249 sec)
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:mrr: = 0.2087999999999999 (0.213 sec)
# INFO:tensorflow:mrr: = 0.2312 (0.262 sec)
# INFO:tensorflow:mrr: = 0.14839999999999995 (0.198 sec)
# INFO:tensorflow:mrr: = 0.19840000000000016 (0.247 sec)
# INFO:tensorflow:mrr: = 0.11839999999999969 (0.217 sec)
# INFO:tensorflow:mrr: = 0.26279999999999987 (0.155 sec)
# INFO:tensorflow:mrr: = 0.25520000000000026 (0.230 sec)
# INFO:tensorflow:mrr: = 0.2079999999999999 (0.203 sec)
# INFO:tensorflow:mrr: = 0.19119999999999993 (0.184 sec)
# INFO:tensorflow:mrr: = 0.2832000000000006 (0.274 sec)
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:mrr: = 0.25120000000000053 (0.249 sec)
# INFO:tensorflow:mrr: = 0.20319999999999955 (0.243 sec)
# INFO:tensorflow:mrr: = 0.23000000000000073 (0.213 sec)
# INFO:tensorflow:mrr: = 0.2124000000000001 (0.257 sec)
# INFO:tensorflow:mrr: = 0.26840000000000047 (0.194 sec)
# INFO:tensorflow:mrr: = 0.18880000000000002 (0.262 sec)
# INFO:tensorflow:mrr: = 0.16080000000000008 (0.277 sec)
# INFO:tensorflow:mrr: = 0.2692000000000003 (0.197 sec)
# INFO:tensorflow:mrr: = 0.22960000000000064 (0.258 sec)
# INFO:tensorflow:mrr: = 0.22640000000000018 (0.271 sec)
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:mrr: = 0.2272000000000001 (0.237 sec)
# INFO:tensorflow:mrr: = 0.19599999999999965 (0.208 sec)
# INFO:tensorflow:mrr: = 0.14279999999999995 (0.294 sec)
# INFO:tensorflow:mrr: = 0.21959999999999977 (0.288 sec)
# INFO:tensorflow:mrr: = 0.25760000000000055 (0.290 sec)
# INFO:tensorflow:mrr: = 0.24480000000000018 (0.439 sec)
# INFO:tensorflow:mrr: = 0.2269440000000003 (0.395 sec)

# %%
# !mkdir model_small_nn
# !mv /tmp/tmp9k77hrcy/* model_small_nn/

# %%
del train_split
del val_split

test = pd.read_csv(os.path.join(PATH, 'test.csv'))
test = test[test['action_type'] == 'clickout item']
test = test[test['reference'].isnull()]
test['reference'].fillna(0, inplace=True)
#test_all['reference'].fillna(0, inplace=True)
# TODO: Use all of the test rows!!!

# %%
inputgen_test = InputGenerator(tokenizers,
                  ['user_id', 'session_id', 'platform', 'device',
                   'interacted_items', 'filters', 'items', 'timestamp'])

same_keys = ['user_id', 'session_id', 'timestamp', 'step']

def get_dataset_test():
  gen_test, types, shapes = inputgen_test.input_generator_gen(test)
  dataset = tf.data.Dataset.from_generator(gen_test, types).padded_batch(500, shapes)
  batch_val = dataset.make_one_shot_iterator().get_next()
  
  return dataset

inv_map = {(v - 1): k for k, v in item_tokenizer.mapping.items()}


small_nn_estimator = tf.estimator.Estimator(
  model_fn=yt_rec_model_fn,
  model_dir='./small_nn_model_fn',
  params=params,
  #config=run_config
)

def save_preds(filename, l_results):
  r = pd.DataFrame(l_results)
  r.to_csv(filename)
  del r
  uploaded = drive.CreateFile({'title': filename})
  uploaded.SetContentFile(os.path.join('/content/drive/My Drive/recsys/',
                                       filename))
  uploaded.Upload()
  print('Uploaded file with ID {}'.format(uploaded.get('id')))

all_count = len(test)
results = []
predictions = yt_rec_estimator.predict(input_fn=get_dataset_test)
test_iter = test.iterrows()
counter = 0
print('All rows: {}'.format(all_count))

# %%
for (index, row), prediction in zip(test_iter, predictions):
  result_row = {}
  for r in same_keys:
    result_row[r] = row[r]
  
  assert row['timestamp'] ==  prediction['timestamp']
  
  prediction['probabilities']
  
  # TODO: add separate score for price and position!

  result_row['item_recommendations'] = ' '.join(item_recommendations)
  
  results.append(result_row)
  counter += 1

  if counter % 1000 == 0:
    print(counter/all_count)
    print('PREDICTIONS: {}'.format(counter))
    
  if counter % 50_000 == 0:
    print(counter/all_count)
    print('PREDICTIONS: {}'.format(counter))
    save_preds('results2/predictions-{}.csv'.format(counter), results)
    del results
    results = []
