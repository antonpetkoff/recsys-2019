# %%
import pandas as pd
import tensorflow as tf
from sklearn.utils import shuffle

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('drive/My Drive/recsys')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PATH = 'data/'
train = pd.read_csv(os.path.join(PATH, 'train.csv'))
train.head()
# Out:
#         user_id     session_id   timestamp  ...  current_filters impressions prices
# 0  00RL8Z82B2Z1  aff3928535f48  1541037460  ...              NaN         NaN    NaN
# 1  00RL8Z82B2Z1  aff3928535f48  1541037522  ...              NaN         NaN    NaN
# 2  00RL8Z82B2Z1  aff3928535f48  1541037522  ...              NaN         NaN    NaN
# 3  00RL8Z82B2Z1  aff3928535f48  1541037532  ...              NaN         NaN    NaN
# 4  00RL8Z82B2Z1  aff3928535f48  1541037532  ...              NaN         NaN    NaN
#
# [5 rows x 12 columns]

# %%
item_metadata = pd.read_csv(os.path.join(PATH, 'item_metadata.csv'))
item_metadata.head()
# Out:
#    item_id                                         properties
# 0     5101  Satellite TV|Golf Course|Airport Shuttle|Cosme...
# 1     5416  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 2     5834  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 3     5910  Satellite TV|Sailing|Cosmetic Mirror|Telephone...
# 4     6066  Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...

# %%
class Tokenizer:
  """
  Mapping ids to ints.
  """
  
  def fit(self, data):
    self.vocabulary = set(data)
    self.mapping = dict(zip(self.vocabulary, range(1, len(self.vocabulary) + 1)))
    return self
    
  def transform(self, data):
    if isinstance(data, list):
      return [self.mapping.get(d, 0) for d in data]
    else:
      return self.mapping.get(data, 0)
    

class ItemTokenizer(Tokenizer):
  def transform(self, data):
    if isinstance(data, list):
      arg = list(map(int, data))
    else:
      arg = int(data)
    return super().transform(arg)

item_tokenizer = ItemTokenizer().fit(item_metadata['item_id'])

# %% [markdown]
# ## Getting only the clickout item actions!

# %%
train = train[train['action_type'] == 'clickout item']
train = train[['reference', 'impressions']]

# %% [markdown]
# ![alt text](https://cdn-images-1.medium.com/max/800/1*yiH5sZI-IBxDSQMKhvbcHw.png
# )

# %% [markdown]
# ## Skip-gram for the items
# based only on the impressions they appear with!

# %% [markdown]
# ### Dataset

# %%
class InputGenerator:
  
  def __init__(self, item_tokenizer):
    self.item_tokenizer = item_tokenizer
    
  def input_generator_gen(self, df):
    def gen():

      for index, row in df.iterrows():
        reference = self.item_tokenizer.transform(row['reference'])
        impressions = self.item_tokenizer.transform(row['impressions'].split('|'))
        
        for impression in impressions:
          if reference == impression:
            continue
          yield reference, [impression]
    return gen, (tf.int32, tf.int32),

i = InputGenerator(item_tokenizer)

# %%
params = {
    'batch_size': 4096,
    'items_vocabulary': len(item_tokenizer.vocabulary),
    'items_embedding': 100,
}
gen, types = i.input_generator_gen(train)
dataset_train = tf.data.Dataset.from_generator(gen, types)
dataset_train = dataset_train.repeat().batch(params['batch_size'])
# batch = dataset_train.make_one_shot_iterator().get_next()

steps_per_epoch = len(train) // params['batch_size']

# %%
tf.logging.set_verbosity(tf.logging.INFO)

# %%
# !rm -r skip-gram-model

# %%
# It can only be trained!
def skip_gram_items(
   features, # This is batch_features from input_fn
   labels,   # This is batch_labels from input_fn
   mode,     # An instance of tf.estimator.ModeKeys, see below
   params):  # Additional configuration
  
  reference = features
  impression = labels
  
  # Encoding
  items_embeddings = tf.keras.layers.Embedding(input_dim=params['items_vocabulary'],
                                               output_dim=params['items_embedding'])
  
  # Reverse encoding
  W2 = tf.Variable(tf.random_normal([params['items_embedding'],
                                     params['items_vocabulary']]))
  b2 = tf.Variable(tf.random_normal([params['items_vocabulary']]))
  
  features.set_shape([None, params['items_embedding']])
  embeddings = tf.reshape(items_embeddings(features), [-1, params['items_embedding']])
  
  layer = tf.matmul(embeddings, W2) + b2
  layer = tf.nn.softmax(layer)
  
  loss = tf.losses.sparse_softmax_cross_entropy(labels=impression,
                                                logits=layer)
  loss = tf.reduce_mean(loss)
  optimizer = tf.train.AdamOptimizer(learning_rate=0.1)
  
  train_op = optimizer.minimize(
    loss=loss,
    global_step=tf.train.get_global_step()
  )
  
  return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)


run_config = tf.estimator.RunConfig(log_step_count_steps=100,
                                    # save_summary_steps=20,
                                    save_checkpoints_steps=100,
                                    keep_checkpoint_max=3)

skipgram_estimator = tf.estimator.Estimator(
  model_fn=skip_gram_items,
  model_dir='./skip-gram-model',
  params=params,
  config=run_config
)

skipgram_estimator.train(input_fn=lambda: tf.data.Dataset.from_generator(gen, types),
                   steps=1000 * steps_per_epoch)
# Out:
# I0621 18:52:41.403447 140585171875712 estimator.py:209] Using config: {'_model_dir': './skip-gram-model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fdbf0610438>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I0621 18:52:41.445034 140585171875712 estimator.py:1145] Calling model_fn.
# I0621 18:52:41.639279 140585171875712 estimator.py:1147] Done calling model_fn.
# I0621 18:52:41.642077 140585171875712 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0621 18:52:41.732873 140585171875712 monitored_session.py:240] Graph was finalized.
# I0621 18:52:41.763834 140585171875712 saver.py:1280] Restoring parameters from ./skip-gram-model/model.ckpt-5157
# I0621 18:52:43.279163 140585171875712 session_manager.py:500] Running local_init_op.
# I0621 18:52:43.287944 140585171875712 session_manager.py:502] Done running local_init_op.
# I0621 18:52:43.472927 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5157 into ./skip-gram-model/model.ckpt.
# I0621 18:52:48.990751 140585171875712 basic_session_run_hooks.py:262] loss = 13.739864, step = 5157
# I0621 18:52:53.037283 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5257 into ./skip-gram-model/model.ckpt.
# I0621 18:52:58.296431 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7454
# I0621 18:52:58.300944 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 5257 (9.310 sec)
# I0621 18:53:02.287795 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5357 into ./skip-gram-model/model.ckpt.
# I0621 18:53:07.597966 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7509
# I0621 18:53:07.602715 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 5357 (9.302 sec)
# I0621 18:53:11.589994 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5457 into ./skip-gram-model/model.ckpt.
# I0621 18:53:16.626519 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.0759
# I0621 18:53:16.632570 140585171875712 basic_session_run_hooks.py:260] loss = 13.7398615, step = 5457 (9.030 sec)
# I0621 18:53:20.626430 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5557 into ./skip-gram-model/model.ckpt.
# I0621 18:53:26.135783 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.5161
# I0621 18:53:26.138074 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 5557 (9.506 sec)
# I0621 18:53:30.135898 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5657 into ./skip-gram-model/model.ckpt.
# I0621 18:53:35.041403 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.2289
# I0621 18:53:35.047949 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 5657 (8.910 sec)
# I0621 18:53:39.036417 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5757 into ./skip-gram-model/model.ckpt.
# I0621 18:53:44.252462 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.8564
# I0621 18:53:44.257728 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 5757 (9.210 sec)
# I0621 18:53:48.242458 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5857 into ./skip-gram-model/model.ckpt.
# I0621 18:53:53.543558 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.763
# I0621 18:53:53.549762 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 5857 (9.292 sec)
# I0621 18:53:57.540187 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5957 into ./skip-gram-model/model.ckpt.
# I0621 18:54:02.847888 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7477
# I0621 18:54:02.853000 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 5957 (9.303 sec)
# I0621 18:54:06.858184 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6057 into ./skip-gram-model/model.ckpt.
# I0621 18:54:12.164042 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7341
# I0621 18:54:12.168394 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 6057 (9.315 sec)
# I0621 18:54:16.169292 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6157 into ./skip-gram-model/model.ckpt.
# I0621 18:54:21.268192 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.984
# I0621 18:54:21.272810 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 6157 (9.104 sec)
# I0621 18:54:25.268280 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6257 into ./skip-gram-model/model.ckpt.
# I0621 18:54:30.720025 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.5799
# I0621 18:54:30.726071 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 6257 (9.453 sec)
# I0621 18:54:34.717193 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6357 into ./skip-gram-model/model.ckpt.
# I0621 18:54:39.702817 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.1325
# I0621 18:54:39.706151 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 6357 (8.980 sec)
# I0621 18:54:43.695202 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6457 into ./skip-gram-model/model.ckpt.
# I0621 18:54:49.019120 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7339
# I0621 18:54:49.021003 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 6457 (9.315 sec)
# I0621 18:54:53.004743 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6557 into ./skip-gram-model/model.ckpt.
# I0621 18:54:58.311192 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7618
# I0621 18:54:58.315202 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 6557 (9.294 sec)
# I0621 18:55:02.306391 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6657 into ./skip-gram-model/model.ckpt.
# I0621 18:55:07.612943 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7506
# I0621 18:55:07.618101 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 6657 (9.303 sec)
# I0621 18:55:11.608420 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6757 into ./skip-gram-model/model.ckpt.
# I0621 18:55:16.593013 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.1358
# I0621 18:55:16.597701 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 6757 (8.980 sec)
# I0621 18:55:20.601430 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6857 into ./skip-gram-model/model.ckpt.
# I0621 18:55:26.087411 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.5325
# I0621 18:55:26.091884 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 6857 (9.494 sec)
# I0621 18:55:30.097107 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6957 into ./skip-gram-model/model.ckpt.
# I0621 18:55:35.566054 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.55
# I0621 18:55:35.570060 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 6957 (9.478 sec)
# I0621 18:55:39.566892 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7057 into ./skip-gram-model/model.ckpt.
# I0621 18:55:44.666949 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.9879
# I0621 18:55:44.668829 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7057 (9.099 sec)
# I0621 18:55:48.660600 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7157 into ./skip-gram-model/model.ckpt.
# I0621 18:55:53.968978 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7504
# I0621 18:55:53.973274 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7157 (9.304 sec)
# I0621 18:55:57.970424 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7257 into ./skip-gram-model/model.ckpt.
# I0621 18:56:03.276117 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7444
# I0621 18:56:03.279083 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7257 (9.306 sec)
# I0621 18:56:07.273058 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7357 into ./skip-gram-model/model.ckpt.
# I0621 18:56:12.424485 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.9309
# I0621 18:56:12.430961 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 7357 (9.152 sec)
# I0621 18:56:16.416091 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7457 into ./skip-gram-model/model.ckpt.
# I0621 18:56:21.458317 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.0695
# I0621 18:56:21.461048 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7457 (9.030 sec)
# I0621 18:56:25.451137 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7557 into ./skip-gram-model/model.ckpt.
# I0621 18:56:30.775623 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7327
# I0621 18:56:30.781163 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7557 (9.320 sec)
# I0621 18:56:34.768615 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7657 into ./skip-gram-model/model.ckpt.
# I0621 18:56:39.775474 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.1113
# I0621 18:56:39.777748 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7657 (8.997 sec)
# I0621 18:56:43.770746 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7757 into ./skip-gram-model/model.ckpt.
# I0621 18:56:49.167148 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.6477
# I0621 18:56:49.173535 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7757 (9.396 sec)
# I0621 18:56:53.153439 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7857 into ./skip-gram-model/model.ckpt.
# I0621 18:56:58.297221 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.9528
# I0621 18:56:58.299906 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7857 (9.126 sec)
# I0621 18:57:02.281932 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7957 into ./skip-gram-model/model.ckpt.
# I0621 18:57:07.803787 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.5191
# I0621 18:57:07.809985 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 7957 (9.510 sec)
# I0621 18:57:11.791848 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8057 into ./skip-gram-model/model.ckpt.
# I0621 18:57:17.205008 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.6369
# I0621 18:57:17.209280 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8057 (9.399 sec)
# I0621 18:57:21.194475 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8157 into ./skip-gram-model/model.ckpt.
# I0621 18:57:26.563426 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.6856
# I0621 18:57:26.567710 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8157 (9.358 sec)
# I0621 18:57:30.553406 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8257 into ./skip-gram-model/model.ckpt.
# I0621 18:57:35.608462 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.0557
# I0621 18:57:35.613739 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8257 (9.046 sec)
# I0621 18:57:39.597948 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8357 into ./skip-gram-model/model.ckpt.
# I0621 18:57:44.855214 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.8146
# I0621 18:57:44.857444 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 8357 (9.244 sec)
# I0621 18:57:48.855227 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8457 into ./skip-gram-model/model.ckpt.
# I0621 18:57:54.363941 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.5167
# I0621 18:57:54.366156 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8457 (9.509 sec)
# I0621 18:57:58.355387 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8557 into ./skip-gram-model/model.ckpt.
# I0621 18:58:03.550760 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.8852
# I0621 18:58:03.553029 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8557 (9.187 sec)
# I0621 18:58:07.535035 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8657 into ./skip-gram-model/model.ckpt.
# I0621 18:58:12.619371 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.027
# I0621 18:58:12.623681 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8657 (9.071 sec)
# I0621 18:58:16.603954 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8757 into ./skip-gram-model/model.ckpt.
# I0621 18:58:21.608276 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.1249
# I0621 18:58:21.613350 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8757 (8.990 sec)
# I0621 18:58:25.601966 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8857 into ./skip-gram-model/model.ckpt.
# I0621 18:58:30.939992 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7161
# I0621 18:58:30.945644 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 8857 (9.332 sec)
# I0621 18:58:34.930783 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8957 into ./skip-gram-model/model.ckpt.
# I0621 18:58:39.854871 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.2172
# I0621 18:58:39.857136 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 8957 (8.912 sec)
# I0621 18:58:43.840317 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9057 into ./skip-gram-model/model.ckpt.
# I0621 18:58:48.860178 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.1045
# I0621 18:58:48.864448 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 9057 (9.007 sec)
# I0621 18:58:52.861977 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9157 into ./skip-gram-model/model.ckpt.
# I0621 18:58:57.666872 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.355
# I0621 18:58:57.672680 140585171875712 basic_session_run_hooks.py:260] loss = 13.739865, step = 9157 (8.808 sec)
# I0621 18:59:01.656882 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9257 into ./skip-gram-model/model.ckpt.
# I0621 18:59:06.820842 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.9242
# I0621 18:59:06.822956 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 9257 (9.150 sec)
# I0621 18:59:10.816424 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9357 into ./skip-gram-model/model.ckpt.
# I0621 18:59:16.086745 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7923
# I0621 18:59:16.091662 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 9357 (9.269 sec)
# I0621 18:59:20.094927 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9457 into ./skip-gram-model/model.ckpt.
# I0621 18:59:25.078681 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.1211
# I0621 18:59:25.085271 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 9457 (8.994 sec)
# I0621 18:59:29.066932 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9557 into ./skip-gram-model/model.ckpt.
# I0621 18:59:34.154826 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.018
# I0621 18:59:34.159864 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 9557 (9.075 sec)
# I0621 18:59:38.147870 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9657 into ./skip-gram-model/model.ckpt.
# I0621 18:59:43.488201 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.7141
# I0621 18:59:43.492661 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 9657 (9.333 sec)
# I0621 18:59:47.480394 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9757 into ./skip-gram-model/model.ckpt.
# I0621 18:59:52.678298 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.8813
# I0621 18:59:52.684222 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 9757 (9.192 sec)
# I0621 18:59:56.682308 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9857 into ./skip-gram-model/model.ckpt.
# I0621 19:00:02.050980 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.6693
# I0621 19:00:02.056592 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 9857 (9.372 sec)
# I0621 19:00:06.047297 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 9957 into ./skip-gram-model/model.ckpt.
# I0621 19:00:11.095804 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.0561
# I0621 19:00:11.098118 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 9957 (9.042 sec)
# I0621 19:00:15.088392 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 10057 into ./skip-gram-model/model.ckpt.
# I0621 19:00:20.170128 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 11.02
# I0621 19:00:20.173174 140585171875712 basic_session_run_hooks.py:260] loss = 13.739864, step = 10057 (9.075 sec)
# I0621 19:00:24.173842 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 10157 into ./skip-gram-model/model.ckpt.
# I0621 19:00:29.527117 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 10.6872
# I0621 19:00:29.529301 140585171875712 basic_session_run_hooks.py:260] loss = 13.739863, step = 10157 (9.356 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-93b88bfc6d76> in <module>()
#      49
#      50 skipgram_estimator.train(input_fn=lambda: tf.data.Dataset.from_generator(gen, types),
# ---> 51                    steps=1000 * steps_per_epoch)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     365
#     366       saving_listeners = _check_listeners_type(saving_listeners)
# --> 367       loss = self._train_model(input_fn, hooks, saving_listeners)
#     368       logging.info('Loss for final step: %s.', loss)
#     369       return self
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1157     else:
# -> 1158       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1159
#    1160   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1190       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1191                                              hooks, global_step_tensor,
# -> 1192                                              saving_listeners)
#    1193
#    1194   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1482       any_step_done = False
#    1483       while not mon_sess.should_stop():
# -> 1484         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1485         any_step_done = True
#    1486     if not any_step_done:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1250             feed_dict=feed_dict,
#    1251             options=options,
# -> 1252             run_metadata=run_metadata)
#    1253       except _PREEMPTION_ERRORS as e:
#    1254         logging.info(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1336   def run(self, *args, **kwargs):
#    1337     try:
# -> 1338       return self._sess.run(*args, **kwargs)
#    1339     except _PREEMPTION_ERRORS:
#    1340       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1409         feed_dict=feed_dict,
#    1410         options=options,
# -> 1411         run_metadata=run_metadata)
#    1412
#    1413     for hook in self._hooks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1167
#    1168   def run(self, *args, **kwargs):
# -> 1169     return self._sess.run(*args, **kwargs)
#    1170
#    1171   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## CBOW for the items

# %%
class InputGeneratorCBOW:
  
  def __init__(self, item_tokenizer):
    self.item_tokenizer = item_tokenizer
    
  def input_generator_gen(self, df):
    def gen():

      for index, row in df.iterrows():
        reference = self.item_tokenizer.transform(row['reference'])
        impressions = self.item_tokenizer.transform(row['impressions'].split('|'))
        
        if reference in impressions:
          impressions.remove(reference)
        yield impressions, [reference]
    return gen, (tf.int32, tf.int32), (tf.TensorShape([None]), tf.TensorShape([None]))
  
i_cbow = InputGeneratorCBOW(item_tokenizer)
params = {
    'batch_size': 256,
    'items_vocabulary': len(item_tokenizer.vocabulary),
    'items_embedding': 50,
}

def get_cbow_dataset():
  gen_cbow, types, shapes = i_cbow.input_generator_gen(train)
  dataset_train = tf.data.Dataset.from_generator(gen_cbow, types)
  dataset_train = dataset_train.repeat().padded_batch(params['batch_size'], shapes)
  return dataset_train

# %%
batch = get_cbow_dataset().make_one_shot_iterator().get_next()

with tf.Session() as sess:
  sess.run([tf.local_variables_initializer(), tf.tables_initializer()])
  b = sess.run(batch)
b
b[1].shape
# Out:
# (256, 1)

# %%
# It can only be trained!
def cbow_items(
   features, # This is batch_features from input_fn
   labels,   # This is batch_labels from input_fn
   mode,     # An instance of tf.estimator.ModeKeys, see below
   params):  # Additional configuration

  # In CBOW we predict the target REFERENCE from the context IMPRESSIONS.
  reference = labels
  impressions = features

  # Encoding
  items_embeddings = tf.keras.layers.Embedding(input_dim=params['items_vocabulary'],
                                               output_dim=params['items_embedding'])

  # Reverse encoding
  W2 = tf.Variable(tf.random_normal([params['items_embedding'],
                                     params['items_vocabulary']]))
  b2 = tf.Variable(tf.random_normal([params['items_vocabulary']]))

  embeddings = tf.reduce_mean(items_embeddings(impressions), axis=1)

  layer = tf.matmul(embeddings, W2) + b2
  # layer = tf.nn.softmax(layer)

  loss = tf.losses.sparse_softmax_cross_entropy(labels=tf.reshape(reference, [-1]),
                                                logits=layer)
  loss = tf.reduce_mean(loss)
  optimizer = tf.train.AdamOptimizer(learning_rate=0.0000001)

  train_op = optimizer.minimize(
    loss=loss,
    global_step=tf.train.get_global_step()
  )

  return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)


run_config = tf.estimator.RunConfig(log_step_count_steps=30,
                                  # save_summary_steps=20,
                                  save_checkpoints_steps=100,
                                  keep_checkpoint_max=3)

cbow_estimator = tf.estimator.Estimator(
model_fn=cbow_items,
model_dir='./cbow-model',
params=params,
config=run_config
)

cbow_estimator.train(input_fn=get_cbow_dataset,
                 steps=1000 * steps_per_epoch)
# Out:
# I0621 19:41:33.493898 140585171875712 estimator.py:209] Using config: {'_model_dir': './cbow-model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 30, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fdc06221c50>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I0621 19:41:33.549085 140585171875712 estimator.py:1145] Calling model_fn.
# I0621 19:41:34.047994 140585171875712 estimator.py:1147] Done calling model_fn.
# I0621 19:41:34.051794 140585171875712 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0621 19:41:34.141595 140585171875712 monitored_session.py:240] Graph was finalized.
# I0621 19:41:34.158626 140585171875712 saver.py:1280] Restoring parameters from ./cbow-model/model.ckpt-2600
# I0621 19:41:35.822122 140585171875712 session_manager.py:500] Running local_init_op.
# I0621 19:41:35.833500 140585171875712 session_manager.py:502] Done running local_init_op.
# I0621 19:41:36.030335 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 2600 into ./cbow-model/model.ckpt.
# I0621 19:41:41.663024 140585171875712 basic_session_run_hooks.py:262] loss = 14.233532, step = 2600
# I0621 19:41:48.166403 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.61262
# I0621 19:41:48.167953 140585171875712 basic_session_run_hooks.py:260] loss = 14.25993, step = 2630 (6.505 sec)
# I0621 19:41:54.531706 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71307
# I0621 19:41:54.533155 140585171875712 basic_session_run_hooks.py:260] loss = 14.082279, step = 2660 (6.365 sec)
# I0621 19:42:00.903435 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70831
# I0621 19:42:00.905478 140585171875712 basic_session_run_hooks.py:260] loss = 14.208455, step = 2690 (6.372 sec)
# I0621 19:42:02.874474 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 2700 into ./cbow-model/model.ckpt.
# I0621 19:42:12.500124 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58694
# I0621 19:42:12.501617 140585171875712 basic_session_run_hooks.py:260] loss = 14.281257, step = 2720 (11.596 sec)
# I0621 19:42:18.875147 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70583
# I0621 19:42:18.877423 140585171875712 basic_session_run_hooks.py:260] loss = 14.307074, step = 2750 (6.376 sec)
# I0621 19:42:25.238382 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71461
# I0621 19:42:25.239873 140585171875712 basic_session_run_hooks.py:260] loss = 14.162007, step = 2780 (6.362 sec)
# I0621 19:42:29.274226 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 2800 into ./cbow-model/model.ckpt.
# I0621 19:42:37.219330 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.50397
# I0621 19:42:37.220782 140585171875712 basic_session_run_hooks.py:260] loss = 14.260294, step = 2810 (11.981 sec)
# I0621 19:42:43.609403 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.695
# I0621 19:42:43.611001 140585171875712 basic_session_run_hooks.py:260] loss = 14.175258, step = 2840 (6.390 sec)
# I0621 19:42:49.961167 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.72291
# I0621 19:42:49.962558 140585171875712 basic_session_run_hooks.py:260] loss = 14.146051, step = 2870 (6.352 sec)
# I0621 19:42:56.128288 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 2900 into ./cbow-model/model.ckpt.
# I0621 19:43:01.637001 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.5694
# I0621 19:43:01.642122 140585171875712 basic_session_run_hooks.py:260] loss = 14.187724, step = 2900 (11.680 sec)
# I0621 19:43:08.020581 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69957
# I0621 19:43:08.022119 140585171875712 basic_session_run_hooks.py:260] loss = 14.216146, step = 2930 (6.380 sec)
# I0621 19:43:14.381166 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71653
# I0621 19:43:14.382684 140585171875712 basic_session_run_hooks.py:260] loss = 14.384026, step = 2960 (6.361 sec)
# I0621 19:43:20.742144 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71625
# I0621 19:43:20.743631 140585171875712 basic_session_run_hooks.py:260] loss = 14.209717, step = 2990 (6.361 sec)
# I0621 19:43:22.663069 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3000 into ./cbow-model/model.ckpt.
# I0621 19:43:32.061768 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.65027
# I0621 19:43:32.063313 140585171875712 basic_session_run_hooks.py:260] loss = 14.1959715, step = 3020 (11.320 sec)
# I0621 19:43:38.435869 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70656
# I0621 19:43:38.437293 140585171875712 basic_session_run_hooks.py:260] loss = 14.213451, step = 3050 (6.374 sec)
# I0621 19:43:44.782559 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.72687
# I0621 19:43:44.784122 140585171875712 basic_session_run_hooks.py:260] loss = 14.186217, step = 3080 (6.347 sec)
# I0621 19:43:48.821339 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3100 into ./cbow-model/model.ckpt.
# I0621 19:43:56.570986 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.54487
# I0621 19:43:56.572520 140585171875712 basic_session_run_hooks.py:260] loss = 14.299483, step = 3110 (11.788 sec)
# I0621 19:44:02.968042 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68966
# I0621 19:44:02.969691 140585171875712 basic_session_run_hooks.py:260] loss = 14.228691, step = 3140 (6.397 sec)
# I0621 19:44:09.338680 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7091
# I0621 19:44:09.340140 140585171875712 basic_session_run_hooks.py:260] loss = 14.268897, step = 3170 (6.370 sec)
# I0621 19:44:15.483053 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3200 into ./cbow-model/model.ckpt.
# I0621 19:44:20.970161 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.57919
# I0621 19:44:20.975036 140585171875712 basic_session_run_hooks.py:260] loss = 14.312478, step = 3200 (11.635 sec)
# I0621 19:44:27.395214 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66926
# I0621 19:44:27.396786 140585171875712 basic_session_run_hooks.py:260] loss = 14.262008, step = 3230 (6.422 sec)
# I0621 19:44:33.759429 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71387
# I0621 19:44:33.760968 140585171875712 basic_session_run_hooks.py:260] loss = 14.250023, step = 3260 (6.364 sec)
# I0621 19:44:40.126023 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71209
# I0621 19:44:40.127552 140585171875712 basic_session_run_hooks.py:260] loss = 14.301603, step = 3290 (6.367 sec)
# I0621 19:44:42.051274 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3300 into ./cbow-model/model.ckpt.
# I0621 19:44:51.668110 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.59918
# I0621 19:44:51.669589 140585171875712 basic_session_run_hooks.py:260] loss = 14.20718, step = 3320 (11.542 sec)
# I0621 19:44:58.104751 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66082
# I0621 19:44:58.106275 140585171875712 basic_session_run_hooks.py:260] loss = 14.16636, step = 3350 (6.437 sec)
# I0621 19:45:04.475903 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7087
# I0621 19:45:04.477394 140585171875712 basic_session_run_hooks.py:260] loss = 14.136286, step = 3380 (6.371 sec)
# I0621 19:45:08.502041 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3400 into ./cbow-model/model.ckpt.
# I0621 19:45:15.844575 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.63884
# I0621 19:45:15.845927 140585171875712 basic_session_run_hooks.py:260] loss = 14.233195, step = 3410 (11.369 sec)
# I0621 19:45:22.259572 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67655
# I0621 19:45:22.261162 140585171875712 basic_session_run_hooks.py:260] loss = 14.308577, step = 3440 (6.415 sec)
# I0621 19:45:28.629391 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7097
# I0621 19:45:28.631099 140585171875712 basic_session_run_hooks.py:260] loss = 14.204351, step = 3470 (6.370 sec)
# I0621 19:45:34.789890 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3500 into ./cbow-model/model.ckpt.
# I0621 19:45:40.216394 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58911
# I0621 19:45:40.221215 140585171875712 basic_session_run_hooks.py:260] loss = 14.188099, step = 3500 (11.590 sec)
# I0621 19:45:46.598137 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7009
# I0621 19:45:46.599682 140585171875712 basic_session_run_hooks.py:260] loss = 14.381023, step = 3530 (6.378 sec)
# I0621 19:45:52.971166 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70732
# I0621 19:45:52.972439 140585171875712 basic_session_run_hooks.py:260] loss = 14.493956, step = 3560 (6.373 sec)
# I0621 19:45:59.343132 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70816
# I0621 19:45:59.344678 140585171875712 basic_session_run_hooks.py:260] loss = 14.212011, step = 3590 (6.372 sec)
# I0621 19:46:01.276118 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3600 into ./cbow-model/model.ckpt.
# I0621 19:46:10.850829 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.60695
# I0621 19:46:10.852311 140585171875712 basic_session_run_hooks.py:260] loss = 14.218011, step = 3620 (11.508 sec)
# I0621 19:46:17.225141 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70638
# I0621 19:46:17.226537 140585171875712 basic_session_run_hooks.py:260] loss = 14.203896, step = 3650 (6.374 sec)
# I0621 19:46:23.602724 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.704
# I0621 19:46:23.605058 140585171875712 basic_session_run_hooks.py:260] loss = 14.095497, step = 3680 (6.379 sec)
# I0621 19:46:27.663574 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3700 into ./cbow-model/model.ckpt.
# I0621 19:46:35.306810 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.56321
# I0621 19:46:35.308231 140585171875712 basic_session_run_hooks.py:260] loss = 14.121904, step = 3710 (11.703 sec)
# I0621 19:46:41.742458 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6615
# I0621 19:46:41.743902 140585171875712 basic_session_run_hooks.py:260] loss = 14.168732, step = 3740 (6.436 sec)
# I0621 19:46:48.117011 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70625
# I0621 19:46:48.118549 140585171875712 basic_session_run_hooks.py:260] loss = 14.309334, step = 3770 (6.375 sec)
# I0621 19:46:54.274697 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3800 into ./cbow-model/model.ckpt.
# I0621 19:46:59.518623 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.6312
# I0621 19:46:59.524990 140585171875712 basic_session_run_hooks.py:260] loss = 14.285718, step = 3800 (11.406 sec)
# I0621 19:47:05.905965 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69682
# I0621 19:47:05.907225 140585171875712 basic_session_run_hooks.py:260] loss = 14.203735, step = 3830 (6.382 sec)
# I0621 19:47:12.331893 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66857
# I0621 19:47:12.333377 140585171875712 basic_session_run_hooks.py:260] loss = 14.229443, step = 3860 (6.426 sec)
# I0621 19:47:18.881643 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.58033
# I0621 19:47:18.883284 140585171875712 basic_session_run_hooks.py:260] loss = 14.2717085, step = 3890 (6.550 sec)
# I0621 19:47:20.858090 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 3900 into ./cbow-model/model.ckpt.
# I0621 19:47:30.702254 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.53794
# I0621 19:47:30.703791 140585171875712 basic_session_run_hooks.py:260] loss = 14.293766, step = 3920 (11.821 sec)
# I0621 19:47:37.096790 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69151
# I0621 19:47:37.098457 140585171875712 basic_session_run_hooks.py:260] loss = 14.298654, step = 3950 (6.395 sec)
# I0621 19:47:43.478333 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70108
# I0621 19:47:43.479953 140585171875712 basic_session_run_hooks.py:260] loss = 14.339274, step = 3980 (6.381 sec)
# I0621 19:47:47.509466 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4000 into ./cbow-model/model.ckpt.
# I0621 19:47:55.078559 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58615
# I0621 19:47:55.080297 140585171875712 basic_session_run_hooks.py:260] loss = 14.341141, step = 4010 (11.600 sec)
# I0621 19:48:01.520667 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.65691
# I0621 19:48:01.522269 140585171875712 basic_session_run_hooks.py:260] loss = 14.223398, step = 4040 (6.442 sec)
# I0621 19:48:07.882531 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71557
# I0621 19:48:07.884233 140585171875712 basic_session_run_hooks.py:260] loss = 14.268648, step = 4070 (6.362 sec)
# I0621 19:48:14.059997 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4100 into ./cbow-model/model.ckpt.
# I0621 19:48:19.442067 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.59526
# I0621 19:48:19.444428 140585171875712 basic_session_run_hooks.py:260] loss = 14.267723, step = 4100 (11.560 sec)
# I0621 19:48:25.813939 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70819
# I0621 19:48:25.816217 140585171875712 basic_session_run_hooks.py:260] loss = 14.117546, step = 4130 (6.372 sec)
# I0621 19:48:32.217638 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68478
# I0621 19:48:32.219156 140585171875712 basic_session_run_hooks.py:260] loss = 14.260845, step = 4160 (6.403 sec)
# I0621 19:48:38.589185 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70844
# I0621 19:48:38.590718 140585171875712 basic_session_run_hooks.py:260] loss = 14.245664, step = 4190 (6.372 sec)
# I0621 19:48:40.524164 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4200 into ./cbow-model/model.ckpt.
# I0621 19:48:50.413150 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.53722
# I0621 19:48:50.414478 140585171875712 basic_session_run_hooks.py:260] loss = 14.341859, step = 4220 (11.824 sec)
# I0621 19:48:56.799163 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69777
# I0621 19:48:56.800701 140585171875712 basic_session_run_hooks.py:260] loss = 14.204364, step = 4250 (6.386 sec)
# I0621 19:49:03.179975 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7016
# I0621 19:49:03.181382 140585171875712 basic_session_run_hooks.py:260] loss = 14.200966, step = 4280 (6.381 sec)
# I0621 19:49:07.230221 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4300 into ./cbow-model/model.ckpt.
# I0621 19:49:14.665237 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.61204
# I0621 19:49:14.666852 140585171875712 basic_session_run_hooks.py:260] loss = 14.303468, step = 4310 (11.485 sec)
# I0621 19:49:21.094791 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66594
# I0621 19:49:21.096114 140585171875712 basic_session_run_hooks.py:260] loss = 14.306334, step = 4340 (6.429 sec)
# I0621 19:49:27.633685 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.58796
# I0621 19:49:27.635291 140585171875712 basic_session_run_hooks.py:260] loss = 14.325511, step = 4370 (6.539 sec)
# I0621 19:49:33.784548 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4400 into ./cbow-model/model.ckpt.
# I0621 19:49:39.106779 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.6148
# I0621 19:49:39.109124 140585171875712 basic_session_run_hooks.py:260] loss = 14.258113, step = 4400 (11.474 sec)
# I0621 19:49:45.520845 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67725
# I0621 19:49:45.522437 140585171875712 basic_session_run_hooks.py:260] loss = 14.270935, step = 4430 (6.413 sec)
# I0621 19:49:51.898117 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70419
# I0621 19:49:51.900005 140585171875712 basic_session_run_hooks.py:260] loss = 14.21105, step = 4460 (6.378 sec)
# I0621 19:49:58.290053 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6934
# I0621 19:49:58.291706 140585171875712 basic_session_run_hooks.py:260] loss = 14.486834, step = 4490 (6.392 sec)
# I0621 19:50:00.203637 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4500 into ./cbow-model/model.ckpt.
# I0621 19:50:10.192131 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.52057
# I0621 19:50:10.193543 140585171875712 basic_session_run_hooks.py:260] loss = 14.168026, step = 4520 (11.902 sec)
# I0621 19:50:16.600058 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68168
# I0621 19:50:16.601576 140585171875712 basic_session_run_hooks.py:260] loss = 14.333823, step = 4550 (6.408 sec)
# I0621 19:50:22.990608 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69444
# I0621 19:50:22.992113 140585171875712 basic_session_run_hooks.py:260] loss = 14.186072, step = 4580 (6.391 sec)
# I0621 19:50:27.041393 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4600 into ./cbow-model/model.ckpt.
# I0621 19:50:34.624324 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.57871
# I0621 19:50:34.625667 140585171875712 basic_session_run_hooks.py:260] loss = 14.310531, step = 4610 (11.634 sec)
# I0621 19:50:41.095415 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.63601
# I0621 19:50:41.097200 140585171875712 basic_session_run_hooks.py:260] loss = 14.2818, step = 4640 (6.472 sec)
# I0621 19:50:47.506617 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6793
# I0621 19:50:47.508044 140585171875712 basic_session_run_hooks.py:260] loss = 14.161137, step = 4670 (6.411 sec)
# I0621 19:50:53.684462 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4700 into ./cbow-model/model.ckpt.
# I0621 19:50:58.926607 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.62698
# I0621 19:50:58.932443 140585171875712 basic_session_run_hooks.py:260] loss = 14.117147, step = 4700 (11.424 sec)
# I0621 19:51:05.308644 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7007
# I0621 19:51:05.310271 140585171875712 basic_session_run_hooks.py:260] loss = 14.116491, step = 4730 (6.378 sec)
# I0621 19:51:11.696936 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69609
# I0621 19:51:11.698469 140585171875712 basic_session_run_hooks.py:260] loss = 14.233219, step = 4760 (6.388 sec)
# I0621 19:51:18.077670 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7017
# I0621 19:51:18.079392 140585171875712 basic_session_run_hooks.py:260] loss = 14.220959, step = 4790 (6.381 sec)
# I0621 19:51:19.997685 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4800 into ./cbow-model/model.ckpt.
# I0621 19:51:29.635798 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.59556
# I0621 19:51:29.637279 140585171875712 basic_session_run_hooks.py:260] loss = 14.211393, step = 4820 (11.558 sec)
# I0621 19:51:36.038575 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68544
# I0621 19:51:36.040101 140585171875712 basic_session_run_hooks.py:260] loss = 14.382594, step = 4850 (6.403 sec)
# I0621 19:51:42.440376 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68619
# I0621 19:51:42.441687 140585171875712 basic_session_run_hooks.py:260] loss = 14.146089, step = 4880 (6.402 sec)
# I0621 19:51:46.476351 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 4900 into ./cbow-model/model.ckpt.
# I0621 19:51:53.950608 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.60637
# I0621 19:51:53.952160 140585171875712 basic_session_run_hooks.py:260] loss = 14.280128, step = 4910 (11.510 sec)
# I0621 19:52:00.382202 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66452
# I0621 19:52:00.383789 140585171875712 basic_session_run_hooks.py:260] loss = 14.257859, step = 4940 (6.432 sec)
# I0621 19:52:06.787293 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68374
# I0621 19:52:06.788918 140585171875712 basic_session_run_hooks.py:260] loss = 14.31464, step = 4970 (6.405 sec)
# I0621 19:52:12.953298 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5000 into ./cbow-model/model.ckpt.
# I0621 19:52:18.698703 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.5186
# I0621 19:52:18.704066 140585171875712 basic_session_run_hooks.py:260] loss = 14.244106, step = 5000 (11.915 sec)
# I0621 19:52:25.199401 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.61487
# I0621 19:52:25.202240 140585171875712 basic_session_run_hooks.py:260] loss = 14.247801, step = 5030 (6.498 sec)
# I0621 19:52:31.771687 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.56464
# I0621 19:52:31.773495 140585171875712 basic_session_run_hooks.py:260] loss = 14.337291, step = 5060 (6.571 sec)
# I0621 19:52:38.197168 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66887
# I0621 19:52:38.199557 140585171875712 basic_session_run_hooks.py:260] loss = 14.34297, step = 5090 (6.426 sec)
# I0621 19:52:40.125455 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5100 into ./cbow-model/model.ckpt.
# I0621 19:52:49.573324 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.63709
# I0621 19:52:49.575043 140585171875712 basic_session_run_hooks.py:260] loss = 14.138402, step = 5120 (11.375 sec)
# I0621 19:52:55.954811 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70114
# I0621 19:52:55.956227 140585171875712 basic_session_run_hooks.py:260] loss = 14.3313875, step = 5150 (6.381 sec)
# I0621 19:53:02.331423 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70468
# I0621 19:53:02.332955 140585171875712 basic_session_run_hooks.py:260] loss = 14.263355, step = 5180 (6.377 sec)
# I0621 19:53:06.378907 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5200 into ./cbow-model/model.ckpt.
# I0621 19:53:13.956538 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58062
# I0621 19:53:13.958059 140585171875712 basic_session_run_hooks.py:260] loss = 14.19816, step = 5210 (11.625 sec)
# I0621 19:53:20.389925 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66319
# I0621 19:53:20.391635 140585171875712 basic_session_run_hooks.py:260] loss = 14.166793, step = 5240 (6.434 sec)
# I0621 19:53:26.799052 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68081
# I0621 19:53:26.800554 140585171875712 basic_session_run_hooks.py:260] loss = 14.222328, step = 5270 (6.409 sec)
# I0621 19:53:32.972063 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5300 into ./cbow-model/model.ckpt.
# I0621 19:53:38.363224 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.59423
# I0621 19:53:38.368632 140585171875712 basic_session_run_hooks.py:260] loss = 14.205379, step = 5300 (11.568 sec)
# I0621 19:53:44.777225 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67726
# I0621 19:53:44.778619 140585171875712 basic_session_run_hooks.py:260] loss = 14.234595, step = 5330 (6.410 sec)
# I0621 19:53:51.160790 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69959
# I0621 19:53:51.162374 140585171875712 basic_session_run_hooks.py:260] loss = 14.370566, step = 5360 (6.384 sec)
# I0621 19:53:57.565400 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68412
# I0621 19:53:57.567132 140585171875712 basic_session_run_hooks.py:260] loss = 14.251309, step = 5390 (6.405 sec)
# I0621 19:53:59.497559 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5400 into ./cbow-model/model.ckpt.
# I0621 19:54:09.304535 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.55555
# I0621 19:54:09.306204 140585171875712 basic_session_run_hooks.py:260] loss = 14.241729, step = 5420 (11.739 sec)
# I0621 19:54:15.676641 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70802
# I0621 19:54:15.678229 140585171875712 basic_session_run_hooks.py:260] loss = 14.241216, step = 5450 (6.372 sec)
# I0621 19:54:22.087494 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67953
# I0621 19:54:22.089005 140585171875712 basic_session_run_hooks.py:260] loss = 14.053286, step = 5480 (6.411 sec)
# I0621 19:54:26.146908 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5500 into ./cbow-model/model.ckpt.
# I0621 19:54:33.915762 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.5363
# I0621 19:54:33.917344 140585171875712 basic_session_run_hooks.py:260] loss = 14.208522, step = 5510 (11.828 sec)
# I0621 19:54:40.374391 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.64494
# I0621 19:54:40.376642 140585171875712 basic_session_run_hooks.py:260] loss = 14.206502, step = 5540 (6.459 sec)
# I0621 19:54:46.810559 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66118
# I0621 19:54:46.812104 140585171875712 basic_session_run_hooks.py:260] loss = 14.347074, step = 5570 (6.435 sec)
# I0621 19:54:52.987079 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5600 into ./cbow-model/model.ckpt.
# I0621 19:54:58.347302 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.60039
# I0621 19:54:58.352823 140585171875712 basic_session_run_hooks.py:260] loss = 14.251581, step = 5600 (11.541 sec)
# I0621 19:55:04.735459 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69619
# I0621 19:55:04.736945 140585171875712 basic_session_run_hooks.py:260] loss = 14.189682, step = 5630 (6.384 sec)
# I0621 19:55:11.117202 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7009
# I0621 19:55:11.118818 140585171875712 basic_session_run_hooks.py:260] loss = 14.075661, step = 5660 (6.382 sec)
# I0621 19:55:17.528839 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.679
# I0621 19:55:17.530340 140585171875712 basic_session_run_hooks.py:260] loss = 14.331674, step = 5690 (6.412 sec)
# I0621 19:55:19.462276 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5700 into ./cbow-model/model.ckpt.
# I0621 19:55:29.143785 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58287
# I0621 19:55:29.145103 140585171875712 basic_session_run_hooks.py:260] loss = 14.264317, step = 5720 (11.615 sec)
# I0621 19:55:35.548848 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68388
# I0621 19:55:35.554147 140585171875712 basic_session_run_hooks.py:260] loss = 14.302683, step = 5750 (6.409 sec)
# I0621 19:55:41.946342 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6893
# I0621 19:55:41.948092 140585171875712 basic_session_run_hooks.py:260] loss = 14.237666, step = 5780 (6.394 sec)
# I0621 19:55:46.006809 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5800 into ./cbow-model/model.ckpt.
# I0621 19:55:53.377488 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.62439
# I0621 19:55:53.379098 140585171875712 basic_session_run_hooks.py:260] loss = 14.23947, step = 5810 (11.431 sec)
# I0621 19:55:59.825824 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.65241
# I0621 19:55:59.827405 140585171875712 basic_session_run_hooks.py:260] loss = 14.205668, step = 5840 (6.448 sec)
# I0621 19:56:06.258624 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66355
# I0621 19:56:06.260132 140585171875712 basic_session_run_hooks.py:260] loss = 14.18032, step = 5870 (6.433 sec)
# I0621 19:56:12.427998 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 5900 into ./cbow-model/model.ckpt.
# I0621 19:56:18.183494 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.51575
# I0621 19:56:18.188197 140585171875712 basic_session_run_hooks.py:260] loss = 14.271985, step = 5900 (11.928 sec)
# I0621 19:56:24.591809 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68142
# I0621 19:56:24.593313 140585171875712 basic_session_run_hooks.py:260] loss = 14.320791, step = 5930 (6.405 sec)
# I0621 19:56:30.992622 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68692
# I0621 19:56:30.994274 140585171875712 basic_session_run_hooks.py:260] loss = 14.215613, step = 5960 (6.401 sec)
# I0621 19:56:37.391152 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68855
# I0621 19:56:37.392734 140585171875712 basic_session_run_hooks.py:260] loss = 14.065463, step = 5990 (6.398 sec)
# I0621 19:56:39.331327 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6000 into ./cbow-model/model.ckpt.
# I0621 19:56:48.733867 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.64487
# I0621 19:56:48.735385 140585171875712 basic_session_run_hooks.py:260] loss = 14.185103, step = 6020 (11.343 sec)
# I0621 19:56:55.149606 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67599
# I0621 19:56:55.151206 140585171875712 basic_session_run_hooks.py:260] loss = 14.235651, step = 6050 (6.416 sec)
# I0621 19:57:01.549309 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68772
# I0621 19:57:01.550913 140585171875712 basic_session_run_hooks.py:260] loss = 14.229577, step = 6080 (6.400 sec)
# I0621 19:57:05.603240 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6100 into ./cbow-model/model.ckpt.
# I0621 19:57:13.075220 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.60282
# I0621 19:57:13.076771 140585171875712 basic_session_run_hooks.py:260] loss = 14.182008, step = 6110 (11.526 sec)
# I0621 19:57:19.508504 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66326
# I0621 19:57:19.510241 140585171875712 basic_session_run_hooks.py:260] loss = 14.219205, step = 6140 (6.433 sec)
# I0621 19:57:25.948218 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.65859
# I0621 19:57:25.949793 140585171875712 basic_session_run_hooks.py:260] loss = 14.167626, step = 6170 (6.440 sec)
# I0621 19:57:32.126703 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6200 into ./cbow-model/model.ckpt.
# I0621 19:57:37.489210 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.59944
# I0621 19:57:37.493014 140585171875712 basic_session_run_hooks.py:260] loss = 14.1811, step = 6200 (11.543 sec)
# I0621 19:57:44.030586 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.58617
# I0621 19:57:44.032240 140585171875712 basic_session_run_hooks.py:260] loss = 14.269396, step = 6230 (6.539 sec)
# I0621 19:57:50.436601 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68311
# I0621 19:57:50.438029 140585171875712 basic_session_run_hooks.py:260] loss = 14.28335, step = 6260 (6.406 sec)
# I0621 19:57:56.844457 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68179
# I0621 19:57:56.846119 140585171875712 basic_session_run_hooks.py:260] loss = 14.227887, step = 6290 (6.408 sec)
# I0621 19:57:58.774218 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6300 into ./cbow-model/model.ckpt.
# I0621 19:58:08.558330 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.56104
# I0621 19:58:08.559901 140585171875712 basic_session_run_hooks.py:260] loss = 14.279314, step = 6320 (11.714 sec)
# I0621 19:58:14.942197 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69938
# I0621 19:58:14.943711 140585171875712 basic_session_run_hooks.py:260] loss = 14.176586, step = 6350 (6.384 sec)
# I0621 19:58:21.345759 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68492
# I0621 19:58:21.347363 140585171875712 basic_session_run_hooks.py:260] loss = 14.252241, step = 6380 (6.404 sec)
# I0621 19:58:25.408047 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6400 into ./cbow-model/model.ckpt.
# I0621 19:58:32.808929 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.61708
# I0621 19:58:32.810588 140585171875712 basic_session_run_hooks.py:260] loss = 14.227699, step = 6410 (11.463 sec)
# I0621 19:58:39.220931 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67868
# I0621 19:58:39.222413 140585171875712 basic_session_run_hooks.py:260] loss = 14.098666, step = 6440 (6.412 sec)
# I0621 19:58:45.627465 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68271
# I0621 19:58:45.629573 140585171875712 basic_session_run_hooks.py:260] loss = 14.246588, step = 6470 (6.407 sec)
# I0621 19:58:51.804095 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6500 into ./cbow-model/model.ckpt.
# I0621 19:58:57.180518 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.59672
# I0621 19:58:57.184223 140585171875712 basic_session_run_hooks.py:260] loss = 14.208597, step = 6500 (11.555 sec)
# I0621 19:59:03.595869 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67632
# I0621 19:59:03.597404 140585171875712 basic_session_run_hooks.py:260] loss = 14.275272, step = 6530 (6.413 sec)
# I0621 19:59:09.999851 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68458
# I0621 19:59:10.001313 140585171875712 basic_session_run_hooks.py:260] loss = 14.210246, step = 6560 (6.404 sec)
# I0621 19:59:16.399471 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68776
# I0621 19:59:16.400847 140585171875712 basic_session_run_hooks.py:260] loss = 14.168079, step = 6590 (6.400 sec)
# I0621 19:59:18.329386 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6600 into ./cbow-model/model.ckpt.
# I0621 19:59:27.637832 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.66944
# I0621 19:59:27.639606 140585171875712 basic_session_run_hooks.py:260] loss = 14.284471, step = 6620 (11.239 sec)
# I0621 19:59:34.048948 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67937
# I0621 19:59:34.050839 140585171875712 basic_session_run_hooks.py:260] loss = 14.240643, step = 6650 (6.411 sec)
# I0621 19:59:40.544265 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.61868
# I0621 19:59:40.545859 140585171875712 basic_session_run_hooks.py:260] loss = 14.191254, step = 6680 (6.495 sec)
# I0621 19:59:44.594015 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6700 into ./cbow-model/model.ckpt.
# I0621 19:59:52.182668 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.57768
# I0621 19:59:52.184309 140585171875712 basic_session_run_hooks.py:260] loss = 14.354058, step = 6710 (11.638 sec)
# I0621 19:59:58.647533 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.64048
# I0621 19:59:58.649339 140585171875712 basic_session_run_hooks.py:260] loss = 14.235711, step = 6740 (6.465 sec)
# I0621 20:00:05.084242 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66076
# I0621 20:00:05.085944 140585171875712 basic_session_run_hooks.py:260] loss = 14.21386, step = 6770 (6.437 sec)
# I0621 20:00:11.268999 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6800 into ./cbow-model/model.ckpt.
# I0621 20:00:16.617344 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.6012
# I0621 20:00:16.622360 140585171875712 basic_session_run_hooks.py:260] loss = 13.971099, step = 6800 (11.536 sec)
# I0621 20:00:23.007688 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6946
# I0621 20:00:23.009962 140585171875712 basic_session_run_hooks.py:260] loss = 14.233025, step = 6830 (6.388 sec)
# I0621 20:00:29.406089 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68861
# I0621 20:00:29.407622 140585171875712 basic_session_run_hooks.py:260] loss = 14.25911, step = 6860 (6.398 sec)
# I0621 20:00:35.805049 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68829
# I0621 20:00:35.806800 140585171875712 basic_session_run_hooks.py:260] loss = 14.219257, step = 6890 (6.399 sec)
# I0621 20:00:37.744488 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 6900 into ./cbow-model/model.ckpt.
# I0621 20:00:47.213958 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.62952
# I0621 20:00:47.216099 140585171875712 basic_session_run_hooks.py:260] loss = 14.257376, step = 6920 (11.409 sec)
# I0621 20:00:53.628743 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67675
# I0621 20:00:53.630324 140585171875712 basic_session_run_hooks.py:260] loss = 14.277355, step = 6950 (6.414 sec)
# I0621 20:01:00.023462 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69134
# I0621 20:01:00.025019 140585171875712 basic_session_run_hooks.py:260] loss = 14.274534, step = 6980 (6.395 sec)
# I0621 20:01:04.081840 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7000 into ./cbow-model/model.ckpt.
# I0621 20:01:11.357137 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.64698
# I0621 20:01:11.358568 140585171875712 basic_session_run_hooks.py:260] loss = 14.221015, step = 7010 (11.334 sec)
# I0621 20:01:17.768233 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67937
# I0621 20:01:17.769714 140585171875712 basic_session_run_hooks.py:260] loss = 14.335966, step = 7040 (6.411 sec)
# I0621 20:01:24.209434 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.65752
# I0621 20:01:24.210984 140585171875712 basic_session_run_hooks.py:260] loss = 14.189914, step = 7070 (6.441 sec)
# I0621 20:01:30.401345 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7100 into ./cbow-model/model.ckpt.
# I0621 20:01:35.694144 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.61216
# I0621 20:01:35.697955 140585171875712 basic_session_run_hooks.py:260] loss = 14.238087, step = 7100 (11.487 sec)
# I0621 20:01:42.122743 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6667
# I0621 20:01:42.124276 140585171875712 basic_session_run_hooks.py:260] loss = 14.234536, step = 7130 (6.426 sec)
# I0621 20:01:48.514940 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69319
# I0621 20:01:48.516485 140585171875712 basic_session_run_hooks.py:260] loss = 14.262558, step = 7160 (6.392 sec)
# I0621 20:01:54.919641 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68409
# I0621 20:01:54.921193 140585171875712 basic_session_run_hooks.py:260] loss = 14.149405, step = 7190 (6.405 sec)
# I0621 20:01:56.841103 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7200 into ./cbow-model/model.ckpt.
# I0621 20:02:06.743010 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.53734
# I0621 20:02:06.744431 140585171875712 basic_session_run_hooks.py:260] loss = 14.243277, step = 7220 (11.823 sec)
# I0621 20:02:13.147209 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68441
# I0621 20:02:13.148802 140585171875712 basic_session_run_hooks.py:260] loss = 14.217203, step = 7250 (6.404 sec)
# I0621 20:02:19.548222 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68678
# I0621 20:02:19.549743 140585171875712 basic_session_run_hooks.py:260] loss = 14.210973, step = 7280 (6.401 sec)
# I0621 20:02:23.605843 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7300 into ./cbow-model/model.ckpt.
# I0621 20:02:30.858751 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.65239
# I0621 20:02:30.860146 140585171875712 basic_session_run_hooks.py:260] loss = 14.19244, step = 7310 (11.310 sec)
# I0621 20:02:37.274106 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6763
# I0621 20:02:37.275759 140585171875712 basic_session_run_hooks.py:260] loss = 14.26446, step = 7340 (6.416 sec)
# I0621 20:02:43.739433 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.64013
# I0621 20:02:43.741221 140585171875712 basic_session_run_hooks.py:260] loss = 14.146076, step = 7370 (6.465 sec)
# I0621 20:02:50.070078 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7400 into ./cbow-model/model.ckpt.
# I0621 20:02:55.706417 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.50689
# I0621 20:02:55.708737 140585171875712 basic_session_run_hooks.py:260] loss = 14.313107, step = 7400 (11.968 sec)
# I0621 20:03:02.119112 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67824
# I0621 20:03:02.120437 140585171875712 basic_session_run_hooks.py:260] loss = 14.251872, step = 7430 (6.412 sec)
# I0621 20:03:08.496114 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70439
# I0621 20:03:08.497480 140585171875712 basic_session_run_hooks.py:260] loss = 14.295635, step = 7460 (6.377 sec)
# I0621 20:03:14.908843 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67824
# I0621 20:03:14.910389 140585171875712 basic_session_run_hooks.py:260] loss = 14.274327, step = 7490 (6.413 sec)
# I0621 20:03:16.846418 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7500 into ./cbow-model/model.ckpt.
# I0621 20:03:26.269460 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.6407
# I0621 20:03:26.271240 140585171875712 basic_session_run_hooks.py:260] loss = 14.242197, step = 7520 (11.361 sec)
# I0621 20:03:32.661169 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6936
# I0621 20:03:32.662710 140585171875712 basic_session_run_hooks.py:260] loss = 14.303453, step = 7550 (6.391 sec)
# I0621 20:03:39.050324 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69542
# I0621 20:03:39.051926 140585171875712 basic_session_run_hooks.py:260] loss = 14.243169, step = 7580 (6.389 sec)
# I0621 20:03:43.112531 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7600 into ./cbow-model/model.ckpt.
# I0621 20:03:50.580273 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.60193
# I0621 20:03:50.581965 140585171875712 basic_session_run_hooks.py:260] loss = 14.163299, step = 7610 (11.530 sec)
# I0621 20:03:57.001130 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67224
# I0621 20:03:57.002576 140585171875712 basic_session_run_hooks.py:260] loss = 14.188423, step = 7640 (6.421 sec)
# I0621 20:04:03.463926 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.642
# I0621 20:04:03.465613 140585171875712 basic_session_run_hooks.py:260] loss = 14.118729, step = 7670 (6.463 sec)
# I0621 20:04:09.663576 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7700 into ./cbow-model/model.ckpt.
# I0621 20:04:14.898258 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.62367
# I0621 20:04:14.902932 140585171875712 basic_session_run_hooks.py:260] loss = 14.129066, step = 7700 (11.437 sec)
# I0621 20:04:21.318537 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6727
# I0621 20:04:21.319862 140585171875712 basic_session_run_hooks.py:260] loss = 14.335939, step = 7730 (6.417 sec)
# I0621 20:04:27.719801 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68659
# I0621 20:04:27.721221 140585171875712 basic_session_run_hooks.py:260] loss = 14.318673, step = 7760 (6.401 sec)
# I0621 20:04:34.120712 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68683
# I0621 20:04:34.122275 140585171875712 basic_session_run_hooks.py:260] loss = 14.183705, step = 7790 (6.401 sec)
# I0621 20:04:36.048793 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7800 into ./cbow-model/model.ckpt.
# I0621 20:04:46.025537 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.51998
# I0621 20:04:46.027124 140585171875712 basic_session_run_hooks.py:260] loss = 14.245184, step = 7820 (11.905 sec)
# I0621 20:04:52.425503 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68753
# I0621 20:04:52.427023 140585171875712 basic_session_run_hooks.py:260] loss = 14.207002, step = 7850 (6.400 sec)
# I0621 20:04:58.854740 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6662
# I0621 20:04:58.857083 140585171875712 basic_session_run_hooks.py:260] loss = 14.191957, step = 7880 (6.430 sec)
# I0621 20:05:02.900253 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 7900 into ./cbow-model/model.ckpt.
# I0621 20:05:10.050198 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.67965
# I0621 20:05:10.051590 140585171875712 basic_session_run_hooks.py:260] loss = 14.245406, step = 7910 (11.195 sec)
# I0621 20:05:16.497724 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.65298
# I0621 20:05:16.499136 140585171875712 basic_session_run_hooks.py:260] loss = 14.17539, step = 7940 (6.448 sec)
# I0621 20:05:22.947832 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6511
# I0621 20:05:22.949382 140585171875712 basic_session_run_hooks.py:260] loss = 14.241275, step = 7970 (6.450 sec)
# I0621 20:05:29.291542 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8000 into ./cbow-model/model.ckpt.
# I0621 20:05:34.472539 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.60309
# I0621 20:05:34.475126 140585171875712 basic_session_run_hooks.py:260] loss = 14.271107, step = 8000 (11.526 sec)
# I0621 20:05:40.802697 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7392
# I0621 20:05:40.804094 140585171875712 basic_session_run_hooks.py:260] loss = 14.237002, step = 8030 (6.329 sec)
# I0621 20:05:47.080694 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7786
# I0621 20:05:47.082144 140585171875712 basic_session_run_hooks.py:260] loss = 14.285461, step = 8060 (6.278 sec)
# I0621 20:05:53.385970 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.75792
# I0621 20:05:53.387803 140585171875712 basic_session_run_hooks.py:260] loss = 14.137039, step = 8090 (6.306 sec)
# I0621 20:05:55.273001 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8100 into ./cbow-model/model.ckpt.
# I0621 20:06:04.431266 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.71609
# I0621 20:06:04.432775 140585171875712 basic_session_run_hooks.py:260] loss = 14.273725, step = 8120 (11.045 sec)
# I0621 20:06:10.791627 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71669
# I0621 20:06:10.793118 140585171875712 basic_session_run_hooks.py:260] loss = 14.227158, step = 8150 (6.360 sec)
# I0621 20:06:17.120053 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.74053
# I0621 20:06:17.121799 140585171875712 basic_session_run_hooks.py:260] loss = 14.24318, step = 8180 (6.329 sec)
# I0621 20:06:21.107525 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 8200 into ./cbow-model/model.ckpt.
# I0621 20:06:28.294676 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.68469
# I0621 20:06:28.296129 140585171875712 basic_session_run_hooks.py:260] loss = 14.293773, step = 8210 (11.174 sec)
# I0621 20:06:34.622231 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.74106
# I0621 20:06:34.626864 140585171875712 basic_session_run_hooks.py:260] loss = 14.138513, step = 8240 (6.331 sec)
# I0621 20:06:40.956702 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.736
# ...
# I0621 20:40:49.068336 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70583
# I0621 20:40:49.069746 140585171875712 basic_session_run_hooks.py:260] loss = 14.234347, step = 16070 (6.375 sec)
# I0621 20:40:55.246001 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16100 into ./cbow-model/model.ckpt.
# I0621 20:41:00.654373 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58933
# I0621 20:41:00.656644 140585171875712 basic_session_run_hooks.py:260] loss = 14.272863, step = 16100 (11.587 sec)
# I0621 20:41:07.025747 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70853
# I0621 20:41:07.027205 140585171875712 basic_session_run_hooks.py:260] loss = 14.397123, step = 16130 (6.371 sec)
# I0621 20:41:13.373934 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.72576
# I0621 20:41:13.375401 140585171875712 basic_session_run_hooks.py:260] loss = 14.292362, step = 16160 (6.348 sec)
# I0621 20:41:19.733785 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.7171
# I0621 20:41:19.735110 140585171875712 basic_session_run_hooks.py:260] loss = 14.20684, step = 16190 (6.360 sec)
# I0621 20:41:21.658048 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16200 into ./cbow-model/model.ckpt.
# I0621 20:41:31.185527 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.61969
# I0621 20:41:31.187110 140585171875712 basic_session_run_hooks.py:260] loss = 14.302682, step = 16220 (11.452 sec)
# I0621 20:41:37.650567 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.64033
# I0621 20:41:37.652134 140585171875712 basic_session_run_hooks.py:260] loss = 14.214553, step = 16250 (6.465 sec)
# I0621 20:41:44.019993 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71
# I0621 20:41:44.021442 140585171875712 basic_session_run_hooks.py:260] loss = 14.341502, step = 16280 (6.369 sec)
# I0621 20:41:48.067238 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16300 into ./cbow-model/model.ckpt.
# I0621 20:41:55.642903 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58111
# I0621 20:41:55.644455 140585171875712 basic_session_run_hooks.py:260] loss = 14.234491, step = 16310 (11.623 sec)
# I0621 20:42:02.004952 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71546
# I0621 20:42:02.006467 140585171875712 basic_session_run_hooks.py:260] loss = 14.31356, step = 16340 (6.362 sec)
# I0621 20:42:08.360228 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.72047
# I0621 20:42:08.362490 140585171875712 basic_session_run_hooks.py:260] loss = 14.22228, step = 16370 (6.356 sec)
# I0621 20:42:14.505687 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16400 into ./cbow-model/model.ckpt.
# I0621 20:42:19.837426 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.61387
# I0621 20:42:19.843346 140585171875712 basic_session_run_hooks.py:260] loss = 14.303581, step = 16400 (11.481 sec)
# I0621 20:42:26.213461 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70515
# I0621 20:42:26.214813 140585171875712 basic_session_run_hooks.py:260] loss = 14.272181, step = 16430 (6.371 sec)
# I0621 20:42:32.599056 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69807
# I0621 20:42:32.600795 140585171875712 basic_session_run_hooks.py:260] loss = 14.301151, step = 16460 (6.386 sec)
# I0621 20:42:38.968498 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70999
# I0621 20:42:38.969853 140585171875712 basic_session_run_hooks.py:260] loss = 14.2545595, step = 16490 (6.369 sec)
# I0621 20:42:40.881495 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16500 into ./cbow-model/model.ckpt.
# I0621 20:42:50.513267 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.59858
# I0621 20:42:50.514940 140585171875712 basic_session_run_hooks.py:260] loss = 14.1332855, step = 16520 (11.545 sec)
# I0621 20:42:56.890380 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.70432
# I0621 20:42:56.891762 140585171875712 basic_session_run_hooks.py:260] loss = 14.171203, step = 16550 (6.377 sec)
# I0621 20:43:03.257188 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71194
# I0621 20:43:03.258973 140585171875712 basic_session_run_hooks.py:260] loss = 14.369591, step = 16580 (6.367 sec)
# I0621 20:43:07.285721 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16600 into ./cbow-model/model.ckpt.
# I0621 20:43:14.297693 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.71727
# I0621 20:43:14.299185 140585171875712 basic_session_run_hooks.py:260] loss = 14.213405, step = 16610 (11.040 sec)
# I0621 20:43:20.635271 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.73365
# I0621 20:43:20.636827 140585171875712 basic_session_run_hooks.py:260] loss = 14.221952, step = 16640 (6.338 sec)
# I0621 20:43:26.990149 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.72077
# I0621 20:43:26.991606 140585171875712 basic_session_run_hooks.py:260] loss = 14.234165, step = 16670 (6.355 sec)
# I0621 20:43:33.157128 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16700 into ./cbow-model/model.ckpt.
# I0621 20:43:38.684790 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.56528
# I0621 20:43:38.688410 140585171875712 basic_session_run_hooks.py:260] loss = 14.374096, step = 16700 (11.697 sec)
# I0621 20:43:45.046293 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.71587
# I0621 20:43:45.047723 140585171875712 basic_session_run_hooks.py:260] loss = 14.244514, step = 16730 (6.359 sec)
# I0621 20:43:51.385138 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.73273
# I0621 20:43:51.386597 140585171875712 basic_session_run_hooks.py:260] loss = 14.200047, step = 16760 (6.339 sec)
# I0621 20:43:57.770739 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.69811
# I0621 20:43:57.772412 140585171875712 basic_session_run_hooks.py:260] loss = 14.274318, step = 16790 (6.386 sec)
# I0621 20:43:59.699344 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16800 into ./cbow-model/model.ckpt.
# I0621 20:44:09.732283 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.50803
# I0621 20:44:09.734912 140585171875712 basic_session_run_hooks.py:260] loss = 14.132561, step = 16820 (11.962 sec)
# I0621 20:44:16.320826 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.55336
# I0621 20:44:16.322284 140585171875712 basic_session_run_hooks.py:260] loss = 14.133368, step = 16850 (6.587 sec)
# I0621 20:44:22.841202 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.60096
# I0621 20:44:22.842707 140585171875712 basic_session_run_hooks.py:260] loss = 14.294439, step = 16880 (6.520 sec)
# I0621 20:44:26.996356 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 16900 into ./cbow-model/model.ckpt.
# I0621 20:44:34.776547 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.51354
# I0621 20:44:34.778025 140585171875712 basic_session_run_hooks.py:260] loss = 14.133953, step = 16910 (11.935 sec)
# I0621 20:44:41.311645 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.59062
# I0621 20:44:41.313177 140585171875712 basic_session_run_hooks.py:260] loss = 14.124538, step = 16940 (6.535 sec)
# I0621 20:44:47.899563 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.55378
# I0621 20:44:47.901127 140585171875712 basic_session_run_hooks.py:260] loss = 14.277843, step = 16970 (6.588 sec)
# I0621 20:44:54.260639 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 17000 into ./cbow-model/model.ckpt.
# I0621 20:44:59.513450 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.58312
# I0621 20:44:59.517699 140585171875712 basic_session_run_hooks.py:260] loss = 14.220999, step = 17000 (11.617 sec)
# I0621 20:45:06.063973 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.57975
# I0621 20:45:06.065431 140585171875712 basic_session_run_hooks.py:260] loss = 14.19828, step = 17030 (6.548 sec)
# I0621 20:45:12.479082 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.67647
# I0621 20:45:12.480589 140585171875712 basic_session_run_hooks.py:260] loss = 14.231235, step = 17060 (6.415 sec)
# I0621 20:45:18.953468 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.63365
# I0621 20:45:18.955261 140585171875712 basic_session_run_hooks.py:260] loss = 14.2761545, step = 17090 (6.475 sec)
# I0621 20:45:20.970718 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 17100 into ./cbow-model/model.ckpt.
# I0621 20:45:30.797587 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.53291
# I0621 20:45:30.799089 140585171875712 basic_session_run_hooks.py:260] loss = 14.198701, step = 17120 (11.844 sec)
# I0621 20:45:37.286131 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.6235
# I0621 20:45:37.287578 140585171875712 basic_session_run_hooks.py:260] loss = 14.27034, step = 17150 (6.488 sec)
# I0621 20:45:43.714038 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.66716
# I0621 20:45:43.715433 140585171875712 basic_session_run_hooks.py:260] loss = 14.312088, step = 17180 (6.428 sec)
# I0621 20:45:47.792691 140585171875712 basic_session_run_hooks.py:606] Saving checkpoints for 17200 into ./cbow-model/model.ckpt.
# I0621 20:45:55.286842 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 2.5923
# I0621 20:45:55.288300 140585171875712 basic_session_run_hooks.py:260] loss = 14.242736, step = 17210 (11.573 sec)
# I0621 20:46:01.683773 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68974
# I0621 20:46:01.685396 140585171875712 basic_session_run_hooks.py:260] loss = 14.107961, step = 17240 (6.397 sec)
# I0621 20:46:08.085788 140585171875712 basic_session_run_hooks.py:692] global_step/sec: 4.68601
# I0621 20:46:08.087179 140585171875712 basic_session_run_hooks.py:260] loss = 14.109732, step = 17270 (6.402 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-4805caf25dcf> in <module>()
#      49
#      50 cbow_estimator.train(input_fn=get_cbow_dataset,
# ---> 51                  steps=1000 * steps_per_epoch)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     365
#     366       saving_listeners = _check_listeners_type(saving_listeners)
# --> 367       loss = self._train_model(input_fn, hooks, saving_listeners)
#     368       logging.info('Loss for final step: %s.', loss)
#     369       return self
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1157     else:
# -> 1158       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1159
#    1160   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1190       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1191                                              hooks, global_step_tensor,
# -> 1192                                              saving_listeners)
#    1193
#    1194   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1482       any_step_done = False
#    1483       while not mon_sess.should_stop():
# -> 1484         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1485         any_step_done = True
#    1486     if not any_step_done:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1250             feed_dict=feed_dict,
#    1251             options=options,
# -> 1252             run_metadata=run_metadata)
#    1253       except _PREEMPTION_ERRORS as e:
#    1254         logging.info(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1336   def run(self, *args, **kwargs):
#    1337     try:
# -> 1338       return self._sess.run(*args, **kwargs)
#    1339     except _PREEMPTION_ERRORS:
#    1340       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1409         feed_dict=feed_dict,
#    1410         options=options,
# -> 1411         run_metadata=run_metadata)
#    1412
#    1413     for hook in self._hooks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1167
#    1168   def run(self, *args, **kwargs):
# -> 1169     return self._sess.run(*args, **kwargs)
#    1170
#    1171   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# !rm -r cbow-model
